# %%
import dotenv
import os

ROOT = os.path.dirname(dotenv.find_dotenv())

# %%
import requests
import matplotlib.pyplot as plt
from tqdm import tqdm
from datetime import datetime
import time


def search_semantic_scholar(query: str, year: int, field_of_study: str) -> list:
    """
    Search Semantic Scholar API for papers in a specific year and field
    """
    base_url = "https://api.semanticscholar.org/graph/v1/paper/search"
    all_papers = []
    offset = 0
    limit = 100

    with tqdm(desc=f"Fetching papers for {year}", unit="batch") as pbar:
        while True:
            params = {
                "query": query,
                "fields": "title,publicationDate,citationCount,url,year",
                "limit": limit,
                "offset": offset,
                "year": str(year),
                "fieldsOfStudy": field_of_study,
            }
            while True:
                response = requests.get(base_url, params=params)

                if response.status_code == 429:
                    time.sleep(10)
                    continue

                if response.status_code != 200:
                    break

                break

            if response.status_code != 200:
                break

            data = response.json()
            batch_papers = data.get("data", [])

            all_papers.extend(batch_papers)
            pbar.update(len(batch_papers))
            pbar.set_description(f"Year {year}: {len(all_papers)} papers")

            if len(batch_papers) < limit:
                break

            offset += limit
    return all_papers


def create_scatter_plot(all_years_papers, title="", output_file="plot.png"):
    """
    Create scatter plot across multiple years
    """
    valid_papers = []
    for papers in all_years_papers:
        for paper in papers:
            try:
                pub_date = datetime.fromisoformat(
                    paper.get("publicationDate", "").rstrip("Z")
                )
                if pub_date and paper.get("citationCount") is not None:
                    valid_papers.append(
                        {
                            "date": pub_date,
                            "citations": paper["citationCount"],
                            "title": paper["title"],
                        }
                    )
            except (ValueError, TypeError, AttributeError):
                continue

    dates = [paper["date"] for paper in valid_papers]
    citations = [paper["citations"] for paper in valid_papers]

    plt.figure(figsize=(15, 8))
    scatter = plt.scatter(dates, citations, alpha=0.7, c=citations, cmap="viridis")
    plt.colorbar(scatter, label="Citation Count")
    plt.title(title)
    plt.xlabel("Publication Date")
    plt.ylabel("Citation Count")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(output_file, dpi=300, bbox_inches="tight")

    return valid_papers

# %%
# Main execution
query = "large language model evaluation"
field_of_study = "Computer Science"

# Search for papers by year
years = range(2010, 2011)
all_years_papers = [
    search_semantic_scholar(query, year, field_of_study) for year in years
]

# Create scatter plot
analyzed_papers = create_scatter_plot(
    all_years_papers,
    "Large Language Model Evaluation",
    "large_language_model_evaluation.png",
)
print(f"Total analyzed papers: {len(analyzed_papers)}")
# Out:
# Year 2010: 1000 papers: : 1000batch [00:14, 68.10batch/s]
# Total analyzed papers: 752

# %%
all_years_papers
# Out:
# [[{'paperId': '1b26141ba502a3ea6afdeba1dde43b412ffaff51',
#    'url': 'https://www.semanticscholar.org/paper/1b26141ba502a3ea6afdeba1dde43b412ffaff51',
#    'title': 'Large-Scale Language Modeling with Random Forests for Mandarin Chinese Speech-to-Text',
#    'year': 2010,
#    'citationCount': 2,
#    'publicationDate': '2010-08-16'},
#   {'paperId': '1e12e6ba020ba2b82e63e319d1afbf90a679c10c',
#    'url': 'https://www.semanticscholar.org/paper/1e12e6ba020ba2b82e63e319d1afbf90a679c10c',
#    'title': 'Soft margin estimation of Gaussian mixture model parameters for spoken language recognition',
#    'year': 2010,
#    'citationCount': 4,
#    'publicationDate': '2010-03-14'},
#   {'paperId': '1c0becf051dd81f46ddc597f15bfe330afed2ff5',
#    'url': 'https://www.semanticscholar.org/paper/1c0becf051dd81f46ddc597f15bfe330afed2ff5',
#    'title': 'Practical Evaluation of Speech Recognizers for Virtual Human Dialogue Systems',
#    'year': 2010,
#    'citationCount': 16,
#    'publicationDate': '2010-05-01'},
#   {'paperId': 'c7c301793b98784e5e6a3de30fa978c2a74c70c4',
#    'url': 'https://www.semanticscholar.org/paper/c7c301793b98784e5e6a3de30fa978c2a74c70c4',
#    'title': 'Bootstrapping Language Neutral Term Extraction',
#    'year': 2010,
#    'citationCount': 19,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '82bb25095bbacf71360c7fb24e3cb0fbb4ffb3f5',
#    'url': 'https://www.semanticscholar.org/paper/82bb25095bbacf71360c7fb24e3cb0fbb4ffb3f5',
#    'title': 'Decoding with shrinkage-based language models',
#    'year': 2010,
#    'citationCount': 11,
#    'publicationDate': None},
#   {'paperId': '8856db6abd1c472911b8ac31158cedf4815fac70',
#    'url': 'https://www.semanticscholar.org/paper/8856db6abd1c472911b8ac31158cedf4815fac70',
#    'title': 'The Noisy Channel Model for Unsupervised Word Sense Disambiguation',
#    'year': 2010,
#    'citationCount': 31,
#    'publicationDate': '2010-03-01'},
#   {'paperId': '0e326f07e6aad11deb09ee9bd7448c6b87fc74bc',
#    'url': 'https://www.semanticscholar.org/paper/0e326f07e6aad11deb09ee9bd7448c6b87fc74bc',
#    'title': 'Estonian Large Vocabulary Speech Recognition System for Radiology',
#    'year': 2010,
#    'citationCount': 6,
#    'publicationDate': '2010-08-08'},
#   {'paperId': 'f1ae781dfe425c8026a20dbb474770b696cfb172',
#    'url': 'https://www.semanticscholar.org/paper/f1ae781dfe425c8026a20dbb474770b696cfb172',
#    'title': 'Complex event extraction at PubMed scale',
#    'year': 2010,
#    'citationCount': 128,
#    'publicationDate': '2010-06-01'},
#   {'paperId': '2984ac20f99e4cdb685cca0875fb9aa9b5724911',
#    'url': 'https://www.semanticscholar.org/paper/2984ac20f99e4cdb685cca0875fb9aa9b5724911',
#    'title': 'Estimation Method of User Satisfaction Using N-gram-based Dialog History Model for Spoken Dialog System',
#    'year': 2010,
#    'citationCount': 40,
#    'publicationDate': '2010-05-01'},
#   {'paperId': 'b34462574c6b73712ebb1e306638b3bb70035781',
#    'url': 'https://www.semanticscholar.org/paper/b34462574c6b73712ebb1e306638b3bb70035781',
#    'title': 'GEMS: Generative Modeling for Evaluation of Summaries',
#    'year': 2010,
#    'citationCount': 9,
#    'publicationDate': '2010-03-21'},
#   {'paperId': 'c1562f35362c78145793333da0f69f0cd84ec05b',
#    'url': 'https://www.semanticscholar.org/paper/c1562f35362c78145793333da0f69f0cd84ec05b',
#    'title': 'On the need for data flow graph visualization of Forensic Lucid programs and encoded evidence, and their evaluation by GIPSY',
#    'year': 2010,
#    'citationCount': 9,
#    'publicationDate': '2010-09-27'},
#   {'paperId': 'ffc133e963b1a9af23c6bcf905bfcc545ea0cb5f',
#    'url': 'https://www.semanticscholar.org/paper/ffc133e963b1a9af23c6bcf905bfcc545ea0cb5f',
#    'title': 'Improved language recognition using mixture components statistics',
#    'year': 2010,
#    'citationCount': 9,
#    'publicationDate': None},
#   {'paperId': '3d59573b59b4a6dfa570a9a1b8e95f14a0753b24',
#    'url': 'https://www.semanticscholar.org/paper/3d59573b59b4a6dfa570a9a1b8e95f14a0753b24',
#    'title': 'Diacritics Restoration in Vietnamese: Letter Based vs. Syllable Based Model',
#    'year': 2010,
#    'citationCount': 19,
#    'publicationDate': '2010-08-30'},
#   {'paperId': 'e920936c046dc5c8f3b796df8bb0662686d51d2b',
#    'url': 'https://www.semanticscholar.org/paper/e920936c046dc5c8f3b796df8bb0662686d51d2b',
#    'title': 'Classification of hand postures based on 3D vision model for human-robot interaction',
#    'year': 2010,
#    'citationCount': 17,
#    'publicationDate': '2010-10-11'},
#   {'paperId': '70714275019c2c2c91b766d131e2ba455343976d',
#    'url': 'https://www.semanticscholar.org/paper/70714275019c2c2c91b766d131e2ba455343976d',
#    'title': 'Segmentation, Indexing, and Retrieval for Environmental and Natural Sounds',
#    'year': 2010,
#    'citationCount': 71,
#    'publicationDate': '2010-03-01'},
#   {'paperId': '2f0af930c439f575f1ac0dc99b524835efb8ea3a',
#    'url': 'https://www.semanticscholar.org/paper/2f0af930c439f575f1ac0dc99b524835efb8ea3a',
#    'title': 'Language Modeling Approach for Retrieving Passages in Lecture Audio Data',
#    'year': 2010,
#    'citationCount': 3,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '8f715f46fa230a7e97dc351bdd6a09f2720ca0b7',
#    'url': 'https://www.semanticscholar.org/paper/8f715f46fa230a7e97dc351bdd6a09f2720ca0b7',
#    'title': 'Using an Error-Annotated Learner Corpus to Develop an ESL/EFL Error Correction System',
#    'year': 2010,
#    'citationCount': 59,
#    'publicationDate': '2010-05-01'},
#   {'paperId': 'ed6aaf3422638d94e46a440bb8a82964cfea25c5',
#    'url': 'https://www.semanticscholar.org/paper/ed6aaf3422638d94e46a440bb8a82964cfea25c5',
#    'title': 'Avalanche-safe LINQ compilation',
#    'year': 2010,
#    'citationCount': 62,
#    'publicationDate': '2010-09-01'},
#   {'paperId': '5245d7d59557134872b2f59270020ab4030da2b3',
#    'url': 'https://www.semanticscholar.org/paper/5245d7d59557134872b2f59270020ab4030da2b3',
#    'title': 'Discriminative Word Alignment by Linear Modeling',
#    'year': 2010,
#    'citationCount': 48,
#    'publicationDate': '2010-09-01'},
#   {'paperId': '807382493aa6fa97821aad8544088fd65e10a2a7',
#    'url': 'https://www.semanticscholar.org/paper/807382493aa6fa97821aad8544088fd65e10a2a7',
#    'title': 'The OTIM Formal Annotation Model: A Preliminary Step before Annotation Scheme',
#    'year': 2010,
#    'citationCount': 5,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '46612d0525761b50dfc9bd88d7b11e61aae57caa',
#    'url': 'https://www.semanticscholar.org/paper/46612d0525761b50dfc9bd88d7b11e61aae57caa',
#    'title': 'FOLKER: An Annotation Tool for Efficient Transcription of Natural, Multi-party Interaction',
#    'year': 2010,
#    'citationCount': 35,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '73a8e30fc1d2fda62ef88c048b5cefc3462d772f',
#    'url': 'https://www.semanticscholar.org/paper/73a8e30fc1d2fda62ef88c048b5cefc3462d772f',
#    'title': 'Traceable data types for self-adjusting computation',
#    'year': 2010,
#    'citationCount': 29,
#    'publicationDate': '2010-06-05'},
#   {'paperId': '6f6bf68b1ef5c88175fc3c03773d25dace9c4768',
#    'url': 'https://www.semanticscholar.org/paper/6f6bf68b1ef5c88175fc3c03773d25dace9c4768',
#    'title': 'Retrieval of Similar Electronic Health Records Using UMLS Concept Graphs',
#    'year': 2010,
#    'citationCount': 31,
#    'publicationDate': '2010-06-23'},
#   {'paperId': 'eacbfda79c79a7682c7c1cdce1949b7039321cb2',
#    'url': 'https://www.semanticscholar.org/paper/eacbfda79c79a7682c7c1cdce1949b7039321cb2',
#    'title': 'Study on Emergency Distribution Strategy Based on Ant Colony Algorithm with RBF Neural Network Model',
#    'year': 2010,
#    'citationCount': 1,
#    'publicationDate': '2010-09-09'},
#   {'paperId': '8a93f6ab3a50b7d0a77c4f057abc4eb388268c40',
#    'url': 'https://www.semanticscholar.org/paper/8a93f6ab3a50b7d0a77c4f057abc4eb388268c40',
#    'title': 'Using Comparable Corpora to Adapt a Translation Model to Domains',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '83d50acd65840f0ef873f02d3436ae9a5b1b634b',
#    'url': 'https://www.semanticscholar.org/paper/83d50acd65840f0ef873f02d3436ae9a5b1b634b',
#    'title': 'Training Universal Background Models for Speaker Recognition',
#    'year': 2010,
#    'citationCount': 27,
#    'publicationDate': None},
#   {'paperId': '33bb6500d2c69a5eeb4d8a6d938d0992852d2099',
#    'url': 'https://www.semanticscholar.org/paper/33bb6500d2c69a5eeb4d8a6d938d0992852d2099',
#    'title': 'The GeneReg Corpus for Gene Expression Regulation Events — An Overview of the Corpus and its In-Domain and Out-of-Domain Interoperability',
#    'year': 2010,
#    'citationCount': 22,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '209145ba9c9ddef356b797f88e73ddf0f045fbb7',
#    'url': 'https://www.semanticscholar.org/paper/209145ba9c9ddef356b797f88e73ddf0f045fbb7',
#    'title': 'Statistical machine translation of systems for Sinhala - Tamil',
#    'year': 2010,
#    'citationCount': 14,
#    'publicationDate': '2010-11-22'},
#   {'paperId': '10ff83a39a6b89cdc040e0c27e6500050bece005',
#    'url': 'https://www.semanticscholar.org/paper/10ff83a39a6b89cdc040e0c27e6500050bece005',
#    'title': 'GRISP: A Massive Multilingual Terminological Database for Scientific and Technical Domains',
#    'year': 2010,
#    'citationCount': 14,
#    'publicationDate': '2010-05-19'},
#   {'paperId': 'b08cbc52ec886693d95f12b833561405e7f2558d',
#    'url': 'https://www.semanticscholar.org/paper/b08cbc52ec886693d95f12b833561405e7f2558d',
#    'title': 'Improving Proper Name Recognition by Adding Automatically Learned Pronunciation Variants to the Lexicon',
#    'year': 2010,
#    'citationCount': 13,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '6fbe7aa0c9619db10f5df8326f8117d3e7b28542',
#    'url': 'https://www.semanticscholar.org/paper/6fbe7aa0c9619db10f5df8326f8117d3e7b28542',
#    'title': 'Enforcing User Privacy in Web Applications using Erlang',
#    'year': 2010,
#    'citationCount': 14,
#    'publicationDate': '2010-05-01'},
#   {'paperId': 'e89f0676db786ab7d35b3509e8c910393dd1d474',
#    'url': 'https://www.semanticscholar.org/paper/e89f0676db786ab7d35b3509e8c910393dd1d474',
#    'title': 'A Lexicon of French Quotation Verbs for Automatic Quotation Extraction',
#    'year': 2010,
#    'citationCount': 14,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '139515cbf0ede65761f65e1e4eacfb2877d40a1e',
#    'url': 'https://www.semanticscholar.org/paper/139515cbf0ede65761f65e1e4eacfb2877d40a1e',
#    'title': 'UPV-PRHLT English–Spanish System for WMT10',
#    'year': 2010,
#    'citationCount': 6,
#    'publicationDate': '2010-07-15'},
#   {'paperId': '5db5eeb5cbb7c26efbf2bf316cd0d4bcf102a221',
#    'url': 'https://www.semanticscholar.org/paper/5db5eeb5cbb7c26efbf2bf316cd0d4bcf102a221',
#    'title': 'Factor templates for factored machine translation models',
#    'year': 2010,
#    'citationCount': 9,
#    'publicationDate': None},
#   {'paperId': '8b590a2392ee12ace29415fe41ab62e0b013e9f2',
#    'url': 'https://www.semanticscholar.org/paper/8b590a2392ee12ace29415fe41ab62e0b013e9f2',
#    'title': 'Toward benchmarking a general-domain Thai LVCSR System',
#    'year': 2010,
#    'citationCount': 4,
#    'publicationDate': '2010-05-19'},
#   {'paperId': '518fecee4a2428d853c3751c4c8659cdd72b44fd',
#    'url': 'https://www.semanticscholar.org/paper/518fecee4a2428d853c3751c4c8659cdd72b44fd',
#    'title': 'Experiments with Domain Adaptation Methods for Statistical MT : From European Parliament Proceedings to Finnish Newspaper Text',
#    'year': 2010,
#    'citationCount': 1,
#    'publicationDate': None},
#   {'paperId': '4861e1569c6caabd45582447ab081377d6f94322',
#    'url': 'https://www.semanticscholar.org/paper/4861e1569c6caabd45582447ab081377d6f94322',
#    'title': 'Online Spam Detection in Blogs : A Behavior-based Approach',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': 'bb320192ac1b11bef6d73d105a148f392b25b645',
#    'url': 'https://www.semanticscholar.org/paper/bb320192ac1b11bef6d73d105a148f392b25b645',
#    'title': 'Kumoi: A High-Level Scripting Environment for Collective Virtual Machines',
#    'year': 2010,
#    'citationCount': 7,
#    'publicationDate': '2010-12-08'},
#   {'paperId': '511834bb2c5b1807a32c19328711ff2a2a07015e',
#    'url': 'https://www.semanticscholar.org/paper/511834bb2c5b1807a32c19328711ff2a2a07015e',
#    'title': 'A Database Approach to Symbolic Music Content Management',
#    'year': 2010,
#    'citationCount': 4,
#    'publicationDate': '2010-06-21'},
#   {'paperId': '210d42a84e58a5c30a1c3152e9193b3b1a9a61fa',
#    'url': 'https://www.semanticscholar.org/paper/210d42a84e58a5c30a1c3152e9193b3b1a9a61fa',
#    'title': 'Application of parallel computing to seismic damage process simulation of an arch dam',
#    'year': 2010,
#    'citationCount': 3,
#    'publicationDate': '2010-06-01'},
#   {'paperId': 'fbaa39dc5993a28fb438dd307557820a2ba372dc',
#    'url': 'https://www.semanticscholar.org/paper/fbaa39dc5993a28fb438dd307557820a2ba372dc',
#    'title': 'Example-Based Automatic Phonetic Transcription',
#    'year': 2010,
#    'citationCount': 3,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '693b942a2e08d2d644cd89e87ab03062d173399c',
#    'url': 'https://www.semanticscholar.org/paper/693b942a2e08d2d644cd89e87ab03062d173399c',
#    'title': 'Assistant decision-making modeling of project site location and its application based on ArcGIS Processing',
#    'year': 2010,
#    'citationCount': 2,
#    'publicationDate': '2010-11-01'},
#   {'paperId': 'eda19ba38a76f0757b6fc75d62ffc12d30b75557',
#    'url': 'https://www.semanticscholar.org/paper/eda19ba38a76f0757b6fc75d62ffc12d30b75557',
#    'title': 'A Flexible Representation of Heterogeneous Annotation Data',
#    'year': 2010,
#    'citationCount': 2,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '560d58e22423d9daeaa5fcaf5764abc5436689ed',
#    'url': 'https://www.semanticscholar.org/paper/560d58e22423d9daeaa5fcaf5764abc5436689ed',
#    'title': 'Utilizing Semantic Equivalence Classes of Japanese Functional Expressions in Translation Rule Acquisition from Parallel Patent Sentences',
#    'year': 2010,
#    'citationCount': 2,
#    'publicationDate': '2010-05-01'},
#   {'paperId': 'dc19e19c36e4310beea33bbd671c543a70556162',
#    'url': 'https://www.semanticscholar.org/paper/dc19e19c36e4310beea33bbd671c543a70556162',
#    'title': 'Opinion Analysis Task of Simplified Chinese Monolingual at NTCIR-8',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': 'a54b4c10fec4bcfcf3e7a0f27b57aa4c66e48a86',
#    'url': 'https://www.semanticscholar.org/paper/a54b4c10fec4bcfcf3e7a0f27b57aa4c66e48a86',
#    'title': '언어 입력 강화를 위한 전자칠판 활용 교수-학습 모형 개발',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': '2010-04-01'},
#   {'paperId': '9b8ca208c349bcc977e18481afe9314da07a9d71',
#    'url': 'https://www.semanticscholar.org/paper/9b8ca208c349bcc977e18481afe9314da07a9d71',
#    'title': 'Exploring a striped XML world',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': '986b0d925fe4f2fb96b9268e55603be99de77fea',
#    'url': 'https://www.semanticscholar.org/paper/986b0d925fe4f2fb96b9268e55603be99de77fea',
#    'title': 'Generic Ontology Learners on Application Domains',
#    'year': 2010,
#    'citationCount': 1,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '9f4749c4075cc86407436d3e404b4cbe5c8123d1',
#    'url': 'https://www.semanticscholar.org/paper/9f4749c4075cc86407436d3e404b4cbe5c8123d1',
#    'title': 'Topic dependent class based language model evaluation on automatic speech recognition',
#    'year': 2010,
#    'citationCount': 7,
#    'publicationDate': '2010-12-01'},
#   {'paperId': 'd7ae785702b63e145ff1d835df2f8c50c09784ea',
#    'url': 'https://www.semanticscholar.org/paper/d7ae785702b63e145ff1d835df2f8c50c09784ea',
#    'title': 'Associative processes between behavioral symbols and a large scale language model',
#    'year': 2010,
#    'citationCount': 7,
#    'publicationDate': '2010-05-03'},
#   {'paperId': 'd70332982233518004f60d8e3bfdbc1c8fc0559e',
#    'url': 'https://www.semanticscholar.org/paper/d70332982233518004f60d8e3bfdbc1c8fc0559e',
#    'title': 'Whole-proteome phylogeny of large dsDNA viruses and parvoviruses through a composition vector method related to dynamical language model',
#    'year': 2010,
#    'citationCount': 28,
#    'publicationDate': '2010-06-22'},
#   {'paperId': 'f7d997a640f2b804676cadb8030d8b2c7bd79d85',
#    'url': 'https://www.semanticscholar.org/paper/f7d997a640f2b804676cadb8030d8b2c7bd79d85',
#    'title': 'On Over-fitting in Model Selection and Subsequent Selection Bias in Performance Evaluation',
#    'year': 2010,
#    'citationCount': 1889,
#    'publicationDate': '2010-03-01'},
#   {'paperId': '6951f61f1ce9b977a5d3a614b359f5a0bcf43f46',
#    'url': 'https://www.semanticscholar.org/paper/6951f61f1ce9b977a5d3a614b359f5a0bcf43f46',
#    'title': 'EVALUATION OF AN ENGLISH LANGUAGE TEACHING PROGRAM AT A PUBLIC UNIVERSITY USING CIPP MODEL',
#    'year': 2010,
#    'citationCount': 49,
#    'publicationDate': None},
#   {'paperId': '83a6cacc126d85c45605797406262677c256a6af',
#    'url': 'https://www.semanticscholar.org/paper/83a6cacc126d85c45605797406262677c256a6af',
#    'title': 'Software Framework for Topic Modelling with Large Corpora',
#    'year': 2010,
#    'citationCount': 4573,
#    'publicationDate': '2010-05-22'},
#   {'paperId': '0862bccb0d4bb38a28052ab72439379b4544474e',
#    'url': 'https://www.semanticscholar.org/paper/0862bccb0d4bb38a28052ab72439379b4544474e',
#    'title': "Model-based automatic evaluation of second-language learner's English segmental duration characteristics",
#    'year': 2010,
#    'citationCount': 3,
#    'publicationDate': '2010-07-01'},
#   {'paperId': '931a103258c96a1230dc5c7e38a1cd0b095b9d62',
#    'url': 'https://www.semanticscholar.org/paper/931a103258c96a1230dc5c7e38a1cd0b095b9d62',
#    'title': 'Learning a language model from continuous speech',
#    'year': 2010,
#    'citationCount': 34,
#    'publicationDate': None},
#   {'paperId': 'c944e57b3807ef77c2910df80584e5fe0397617d',
#    'url': 'https://www.semanticscholar.org/paper/c944e57b3807ef77c2910df80584e5fe0397617d',
#    'title': 'Topic cache language model for speech recognition',
#    'year': 2010,
#    'citationCount': 16,
#    'publicationDate': '2010-03-14'},
#   {'paperId': '7dd5a7c3dd45e50a96154ac4734d1e656ba2a3ec',
#    'url': 'https://www.semanticscholar.org/paper/7dd5a7c3dd45e50a96154ac4734d1e656ba2a3ec',
#    'title': 'Slovak Language Model from Internet Text Data',
#    'year': 2010,
#    'citationCount': 10,
#    'publicationDate': '2010-03-15'},
#   {'paperId': '59756f6a8b99813b7055d1100bcac5de314d087f',
#    'url': 'https://www.semanticscholar.org/paper/59756f6a8b99813b7055d1100bcac5de314d087f',
#    'title': 'Multi-style language model for web scale information retrieval',
#    'year': 2010,
#    'citationCount': 27,
#    'publicationDate': '2010-07-19'},
#   {'paperId': '8341fcca41c780fd3d8d37c3e2871f74704c42b5',
#    'url': 'https://www.semanticscholar.org/paper/8341fcca41c780fd3d8d37c3e2871f74704c42b5',
#    'title': 'A comparative study on methods of Weighted language model training for reranking lvcsr N-best hypotheses',
#    'year': 2010,
#    'citationCount': 27,
#    'publicationDate': '2010-03-14'},
#   {'paperId': '981fec6d9d4b45c2f0f4d80512fe0cf56419b8b1',
#    'url': 'https://www.semanticscholar.org/paper/981fec6d9d4b45c2f0f4d80512fe0cf56419b8b1',
#    'title': 'Near-Synonym Choice using a 5-gram Language Model',
#    'year': 2010,
#    'citationCount': 20,
#    'publicationDate': None},
#   {'paperId': 'a49b87efa99272b007645c4426cb469e4088dfd2',
#    'url': 'https://www.semanticscholar.org/paper/a49b87efa99272b007645c4426cb469e4088dfd2',
#    'title': '基於對照表以及語言模型之簡繁字體轉換 (Chinese Characters Conversion System based on Lookup Table and Language Model) [In Chinese]',
#    'year': 2010,
#    'citationCount': 6,
#    'publicationDate': None},
#   {'paperId': '115d7de2294f10be7ef40b265979c41994ab8659',
#    'url': 'https://www.semanticscholar.org/paper/115d7de2294f10be7ef40b265979c41994ab8659',
#    'title': 'Language model adaptation using Random Forests',
#    'year': 2010,
#    'citationCount': 7,
#    'publicationDate': '2010-03-14'},
#   {'paperId': '587eab9c45bc866150083d4d01f3de3b19fa52de',
#    'url': 'https://www.semanticscholar.org/paper/587eab9c45bc866150083d4d01f3de3b19fa52de',
#    'title': 'Using Dependency Grammar Features in Whole Sentence Maximum Entropy Language Model for Speech Recognition',
#    'year': 2010,
#    'citationCount': 5,
#    'publicationDate': '2010-08-08'},
#   {'paperId': 'ee81336331ec66c1a7e5a0ac5c52afaf312561b5',
#    'url': 'https://www.semanticscholar.org/paper/ee81336331ec66c1a7e5a0ac5c52afaf312561b5',
#    'title': 'A New Bigram-PLSA Language Model for Speech Recognition',
#    'year': 2010,
#    'citationCount': 9,
#    'publicationDate': '2010-02-01'},
#   {'paperId': '9e52a8ca250c8b9c9a4ff7e4a3fee18f249a20d5',
#    'url': 'https://www.semanticscholar.org/paper/9e52a8ca250c8b9c9a4ff7e4a3fee18f249a20d5',
#    'title': 'Hypergeometric Language Model and Zipf-Like Scoring Function for Web Document Similarity Retrieval',
#    'year': 2010,
#    'citationCount': 9,
#    'publicationDate': '2010-10-11'},
#   {'paperId': '2a65311a3cd143d6e25e7cbbdb670d0d23fe5266',
#    'url': 'https://www.semanticscholar.org/paper/2a65311a3cd143d6e25e7cbbdb670d0d23fe5266',
#    'title': 'Using passage-based language model for opinion detection in blogs',
#    'year': 2010,
#    'citationCount': 4,
#    'publicationDate': '2010-03-22'},
#   {'paperId': '205e6ee9e42230492a2339490abfcccad5780863',
#    'url': 'https://www.semanticscholar.org/paper/205e6ee9e42230492a2339490abfcccad5780863',
#    'title': 'A Language Model for Human-machine Dialog: The Reversible Semantic Grammar',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': '1ffb08b5d1ab9961e8bfd7ae735899a369a0c2e3',
#    'url': 'https://www.semanticscholar.org/paper/1ffb08b5d1ab9961e8bfd7ae735899a369a0c2e3',
#    'title': 'Abstraction and model evaluation in category learning',
#    'year': 2010,
#    'citationCount': 27,
#    'publicationDate': '2010-05-01'},
#   {'paperId': 'a2cd4d03695b9d5f4440f38e89e7a39b43ffa7f0',
#    'url': 'https://www.semanticscholar.org/paper/a2cd4d03695b9d5f4440f38e89e7a39b43ffa7f0',
#    'title': 'Discriminatively estimated joint acoustic, duration, and language model for speech recognition',
#    'year': 2010,
#    'citationCount': 26,
#    'publicationDate': '2010-03-14'},
#   {'paperId': 'cda58962ba75bd8d4410aa1f2c6e2e29cc2ef1bb',
#    'url': 'https://www.semanticscholar.org/paper/cda58962ba75bd8d4410aa1f2c6e2e29cc2ef1bb',
#    'title': 'Construction and evaluations of an annotated Chinese conversational corpus in travel domain for the language model of speech recognition',
#    'year': 2010,
#    'citationCount': 3,
#    'publicationDate': None},
#   {'paperId': '106e6f03ed73866e4a7b5b6c7f722c1ea16a882e',
#    'url': 'https://www.semanticscholar.org/paper/106e6f03ed73866e4a7b5b6c7f722c1ea16a882e',
#    'title': 'Dynamic language model adaptation using keyword category classification',
#    'year': 2010,
#    'citationCount': 2,
#    'publicationDate': None},
#   {'paperId': '7c32e01d3b8511fe16d0bd1f385c43f95d2cc772',
#    'url': 'https://www.semanticscholar.org/paper/7c32e01d3b8511fe16d0bd1f385c43f95d2cc772',
#    'title': 'A wafer-scale neuromorphic hardware system for large-scale neural modeling',
#    'year': 2010,
#    'citationCount': 681,
#    'publicationDate': '2010-08-03'},
#   {'paperId': '5528cd8a6e7a9283c83d8d7e2b44353aa735205e',
#    'url': 'https://www.semanticscholar.org/paper/5528cd8a6e7a9283c83d8d7e2b44353aa735205e',
#    'title': 'Implementation and Performance Evaluation of XcalableMP: A Parallel Programming Language for Distributed Memory Systems',
#    'year': 2010,
#    'citationCount': 56,
#    'publicationDate': '2010-09-13'},
#   {'paperId': 'f534df5f5027ca09b5dc0d9a86e44e2deb98ed83',
#    'url': 'https://www.semanticscholar.org/paper/f534df5f5027ca09b5dc0d9a86e44e2deb98ed83',
#    'title': 'An experience in using a tool for evaluating a large set of natural language requirements',
#    'year': 2010,
#    'citationCount': 16,
#    'publicationDate': '2010-03-22'},
#   {'paperId': '32478a09717677f06958cdbbdc3ff1ef15b39ef5',
#    'url': 'https://www.semanticscholar.org/paper/32478a09717677f06958cdbbdc3ff1ef15b39ef5',
#    'title': 'A mean field model of work stealing in large-scale systems',
#    'year': 2010,
#    'citationCount': 106,
#    'publicationDate': '2010-06-12'},
#   {'paperId': 'f34c6ece20d9d6595ad571c83ca48452eb44812d',
#    'url': 'https://www.semanticscholar.org/paper/f34c6ece20d9d6595ad571c83ca48452eb44812d',
#    'title': 'Incremental evaluation of model queries over EMF models',
#    'year': 2010,
#    'citationCount': 115,
#    'publicationDate': '2010-10-03'},
#   {'paperId': 'eb9c924383aca0d137c736a41271d569a12cf518',
#    'url': 'https://www.semanticscholar.org/paper/eb9c924383aca0d137c736a41271d569a12cf518',
#    'title': 'An Introduction to Conditional Random Fields',
#    'year': 2010,
#    'citationCount': 1177,
#    'publicationDate': '2010-11-17'},
#   {'paperId': 'ffc576a481e93505285ec09ce6f49cc1d4695936',
#    'url': 'https://www.semanticscholar.org/paper/ffc576a481e93505285ec09ce6f49cc1d4695936',
#    'title': 'The description of iFlyTek Speech Lab system for NIST2009 Language Recognition Evaluation',
#    'year': 2010,
#    'citationCount': 8,
#    'publicationDate': '2010-11-01'},
#   {'paperId': '16449820534a3944719f489818ab7c20b55b56ff',
#    'url': 'https://www.semanticscholar.org/paper/16449820534a3944719f489818ab7c20b55b56ff',
#    'title': 'Multilingual Information Access Evaluation II. Multimedia Experiments - 10th Workshop of the Cross-Language Evaluation Forum, CLEF 2009, Corfu, Greece, September 30 - October 2, 2009, Revised Selected Papers',
#    'year': 2010,
#    'citationCount': 6,
#    'publicationDate': None},
#   {'paperId': 'c4b4e0bd2eb57d7fdc0c5fa77fd1b5985c908e5c',
#    'url': 'https://www.semanticscholar.org/paper/c4b4e0bd2eb57d7fdc0c5fa77fd1b5985c908e5c',
#    'title': 'A new sociotechnical model for studying health information technology in complex adaptive healthcare systems',
#    'year': 2010,
#    'citationCount': 691,
#    'publicationDate': '2010-10-01'},
#   {'paperId': 'e1ba0f44ad664c157387fa7ff232101af6741154',
#    'url': 'https://www.semanticscholar.org/paper/e1ba0f44ad664c157387fa7ff232101af6741154',
#    'title': 'Discovering large grain sizes in a transparent orthography: Insights from a connectionist model of Italian word naming',
#    'year': 2010,
#    'citationCount': 39,
#    'publicationDate': '2010-03-01'},
#   {'paperId': '4f03d792536ef001f78e683bcfd3f97c6a39ed18',
#    'url': 'https://www.semanticscholar.org/paper/4f03d792536ef001f78e683bcfd3f97c6a39ed18',
#    'title': 'Usability evaluation of multi-device/platform user interfaces generated by model-driven engineering',
#    'year': 2010,
#    'citationCount': 51,
#    'publicationDate': '2010-09-16'},
#   {'paperId': '4c7bfa933c11c7a802c2fa9c1dc475dba36a2bd5',
#    'url': 'https://www.semanticscholar.org/paper/4c7bfa933c11c7a802c2fa9c1dc475dba36a2bd5',
#    'title': 'Hive - a petabyte scale data warehouse using Hadoop',
#    'year': 2010,
#    'citationCount': 1020,
#    'publicationDate': '2010-03-01'},
#   {'paperId': '7ec028ace29244cb74c105327a7e4177a34aa6bd',
#    'url': 'https://www.semanticscholar.org/paper/7ec028ace29244cb74c105327a7e4177a34aa6bd',
#    'title': 'Overview of sciDB: large scale array storage, processing and analysis',
#    'year': 2010,
#    'citationCount': 426,
#    'publicationDate': '2010-06-06'},
#   {'paperId': '4177953b70cd1ade0f15442a0108d6eb5ed910e4',
#    'url': 'https://www.semanticscholar.org/paper/4177953b70cd1ade0f15442a0108d6eb5ed910e4',
#    'title': 'Minimal Perfect Hash Rank: Compact Storage of Large N-gram Language Models',
#    'year': 2010,
#    'citationCount': 1,
#    'publicationDate': None},
#   {'paperId': 'b027400188284adde42b9210ea92cb6ec5c04492',
#    'url': 'https://www.semanticscholar.org/paper/b027400188284adde42b9210ea92cb6ec5c04492',
#    'title': 'A Visual Specification Language for Model-to-Model Transformations',
#    'year': 2010,
#    'citationCount': 36,
#    'publicationDate': '2010-09-21'},
#   {'paperId': '5964e4e2ba849ecb5a73b02f2c733969e42a77a0',
#    'url': 'https://www.semanticscholar.org/paper/5964e4e2ba849ecb5a73b02f2c733969e42a77a0',
#    'title': 'Malay language modeling in large vocabulary continuous speech recognition with linguistic information',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': 'bc604e87a399ff5f24a4e8b6dc57277363a64985',
#    'url': 'https://www.semanticscholar.org/paper/bc604e87a399ff5f24a4e8b6dc57277363a64985',
#    'title': 'Evaluation of a Performance Model of Lustre File System',
#    'year': 2010,
#    'citationCount': 30,
#    'publicationDate': '2010-07-16'},
#   {'paperId': '72c2958810686a4f6efde55095b14c66720e782d',
#    'url': 'https://www.semanticscholar.org/paper/72c2958810686a4f6efde55095b14c66720e782d',
#    'title': 'The HiBench benchmark suite: Characterization of the MapReduce-based data analysis',
#    'year': 2010,
#    'citationCount': 763,
#    'publicationDate': '2010-03-01'},
#   {'paperId': '329faa0fe6c1b433110423bd4b28306edc3c0624',
#    'url': 'https://www.semanticscholar.org/paper/329faa0fe6c1b433110423bd4b28306edc3c0624',
#    'title': 'Large Lexicon Project: American Sign Language Video Corpus and Sign Language Indexing/Retrieval Algorithms',
#    'year': 2010,
#    'citationCount': 39,
#    'publicationDate': None},
#   {'paperId': 'de5e14cf754a5bc455433d62baaf011d8182e51e',
#    'url': 'https://www.semanticscholar.org/paper/de5e14cf754a5bc455433d62baaf011d8182e51e',
#    'title': 'Empirical Methods in Natural Language Generation: Data-oriented Methods and Empirical Evaluation',
#    'year': 2010,
#    'citationCount': 39,
#    'publicationDate': '2010-09-01'},
#   {'paperId': 'db259d5b5e6755306ceedca09bfe2a04d5f13696',
#    'url': 'https://www.semanticscholar.org/paper/db259d5b5e6755306ceedca09bfe2a04d5f13696',
#    'title': 'Comparing Rating Scales and Preference Judgements in Language Evaluation',
#    'year': 2010,
#    'citationCount': 41,
#    'publicationDate': '2010-07-07'},
#   {'paperId': '5e7aa935eb3abb811b86fdb83752fceda0052e5f',
#    'url': 'https://www.semanticscholar.org/paper/5e7aa935eb3abb811b86fdb83752fceda0052e5f',
#    'title': 'The development and evaluation of a survey to measure user engagement',
#    'year': 2010,
#    'citationCount': 821,
#    'publicationDate': None},
#   {'paperId': 'b03d9d578ce63574014134a2ad6a6f84a15cb9a6',
#    'url': 'https://www.semanticscholar.org/paper/b03d9d578ce63574014134a2ad6a6f84a15cb9a6',
#    'title': "Don't follow me: Spam detection in Twitter",
#    'year': 2010,
#    'citationCount': 630,
#    'publicationDate': '2010-07-26'},
#   {'paperId': '5a4f7c894f4560c3205978d9277d744a910560f6',
#    'url': 'https://www.semanticscholar.org/paper/5a4f7c894f4560c3205978d9277d744a910560f6',
#    'title': 'A Monolingual Tree-based Translation Model for Sentence Simplification',
#    'year': 2010,
#    'citationCount': 437,
#    'publicationDate': '2010-08-23'},
#   {'paperId': 'c982c1cff4a0f5c37dc7ae181b85f3255fce947e',
#    'url': 'https://www.semanticscholar.org/paper/c982c1cff4a0f5c37dc7ae181b85f3255fce947e',
#    'title': 'Loquendo-Politecnico di Torino system for the 2009 NIST Language Recognition Evaluation',
#    'year': 2010,
#    'citationCount': 13,
#    'publicationDate': '2010-03-14'},
#   {'paperId': 'ec6a71bdfa0f9965f6c6f88bbecd4a1944b50e00',
#    'url': 'https://www.semanticscholar.org/paper/ec6a71bdfa0f9965f6c6f88bbecd4a1944b50e00',
#    'title': 'Evaluating goal models within the goal‐oriented requirement language',
#    'year': 2010,
#    'citationCount': 307,
#    'publicationDate': '2010-06-02'},
#   {'paperId': '8b01bfbaf7fe1967dd1b4ce149732b346bbad682',
#    'url': 'https://www.semanticscholar.org/paper/8b01bfbaf7fe1967dd1b4ce149732b346bbad682',
#    'title': 'Parameter and State Model Reduction for Large-Scale Statistical Inverse Problems',
#    'year': 2010,
#    'citationCount': 264,
#    'publicationDate': '2010-08-01'},
#   {'paperId': '7764a4cd8f99756a899a0b70f074c7b3c36b5275',
#    'url': 'https://www.semanticscholar.org/paper/7764a4cd8f99756a899a0b70f074c7b3c36b5275',
#    'title': "Adaptation and evaluation of generic model matching strategies. (Une approche pour l'adaptation et l'évaluation de stratégies génériques d'alignement de modèles)",
#    'year': 2010,
#    'citationCount': 4,
#    'publicationDate': '2010-09-28'},
#   {'paperId': '8c7635bca49d86b50171cce3636993916e62738d',
#    'url': 'https://www.semanticscholar.org/paper/8c7635bca49d86b50171cce3636993916e62738d',
#    'title': 'Large-scale semi-supervised learning for natural language processing',
#    'year': 2010,
#    'citationCount': 8,
#    'publicationDate': None},
#   {'paperId': '63a06a0097e61f59b5be110cd5a4d902fd50ab35',
#    'url': 'https://www.semanticscholar.org/paper/63a06a0097e61f59b5be110cd5a4d902fd50ab35',
#    'title': 'Language identification in code-switching speech using word-based lexical model',
#    'year': 2010,
#    'citationCount': 4,
#    'publicationDate': '2010-11-01'},
#   {'paperId': 'f870981a588f4b4a68080c2c289f0a50c69a54ed',
#    'url': 'https://www.semanticscholar.org/paper/f870981a588f4b4a68080c2c289f0a50c69a54ed',
#    'title': 'Comparison of Large-scale SVM Training Algorithms for Language Recognition',
#    'year': 2010,
#    'citationCount': 6,
#    'publicationDate': None},
#   {'paperId': '4a47b957dce227ec75b5748d3d4038f32d59603c',
#    'url': 'https://www.semanticscholar.org/paper/4a47b957dce227ec75b5748d3d4038f32d59603c',
#    'title': 'Translation evaluation without reference based on user behavior model',
#    'year': 2010,
#    'citationCount': 1,
#    'publicationDate': '2010-08-01'},
#   {'paperId': '682e456a708db1ead0e29bb987154b0917ea75fc',
#    'url': 'https://www.semanticscholar.org/paper/682e456a708db1ead0e29bb987154b0917ea75fc',
#    'title': 'Large margin estimation of n-gram language models for speech recognition via linear programming',
#    'year': 2010,
#    'citationCount': 4,
#    'publicationDate': '2010-03-14'},
#   {'paperId': 'cb1d1b35a429dc6dc7b418892c3f566a230fdfe8',
#    'url': 'https://www.semanticscholar.org/paper/cb1d1b35a429dc6dc7b418892c3f566a230fdfe8',
#    'title': 'Evaluating the Response Time of Large Scale Content Adaptation Systems Using Performance Evaluation Process Algebra',
#    'year': 2010,
#    'citationCount': 4,
#    'publicationDate': '2010-05-23'},
#   {'paperId': 'dffe15811b14f505e5bbb2ea3a213c6cba71f53e',
#    'url': 'https://www.semanticscholar.org/paper/dffe15811b14f505e5bbb2ea3a213c6cba71f53e',
#    'title': 'Parallel Acoustic Model Adaptation for Improving Phonotactic Language Recognition',
#    'year': 2010,
#    'citationCount': 3,
#    'publicationDate': None},
#   {'paperId': 'd6554953543050bba991c58dc637f10fc2474e6e',
#    'url': 'https://www.semanticscholar.org/paper/d6554953543050bba991c58dc637f10fc2474e6e',
#    'title': 'Unbiased offline evaluation of contextual-bandit-based news article recommendation algorithms',
#    'year': 2010,
#    'citationCount': 564,
#    'publicationDate': '2010-03-31'},
#   {'paperId': '8a19dfd6e417bd35a7b04a2adc22549d45b7ad2c',
#    'url': 'https://www.semanticscholar.org/paper/8a19dfd6e417bd35a7b04a2adc22549d45b7ad2c',
#    'title': 'Design, Modeling, and Evaluation of a Scalable Multi-level Checkpointing System',
#    'year': 2010,
#    'citationCount': 583,
#    'publicationDate': '2010-11-13'},
#   {'paperId': '1003666389391aa2a834d973119903a30fe92550',
#    'url': 'https://www.semanticscholar.org/paper/1003666389391aa2a834d973119903a30fe92550',
#    'title': 'Does My Model Work? Evaluation Abstractions of Cognitive Modelers',
#    'year': 2010,
#    'citationCount': 2,
#    'publicationDate': '2010-09-21'},
#   {'paperId': '0e1eb5d47cd0119b15dad54ad0408b535e320337',
#    'url': 'https://www.semanticscholar.org/paper/0e1eb5d47cd0119b15dad54ad0408b535e320337',
#    'title': 'Design and evaluation of novel input devices and interaction techniques for large, high-resolution displays',
#    'year': 2010,
#    'citationCount': 1,
#    'publicationDate': None},
#   {'paperId': '5d9a3036181676e187c9c0ff995d8bed1db3557d',
#    'url': 'https://www.semanticscholar.org/paper/5d9a3036181676e187c9c0ff995d8bed1db3557d',
#    'title': 'Adapting Visual Category Models to New Domains',
#    'year': 2010,
#    'citationCount': 2838,
#    'publicationDate': '2010-09-05'},
#   {'paperId': '6537aaceb8f768da147b4f316430158fae70f1b5',
#    'url': 'https://www.semanticscholar.org/paper/6537aaceb8f768da147b4f316430158fae70f1b5',
#    'title': 'WikiNet: A Very Large Scale Multi-Lingual Concept Network',
#    'year': 2010,
#    'citationCount': 108,
#    'publicationDate': None},
#   {'paperId': 'a4b9017d86475d6140949c1136047c6f0d101467',
#    'url': 'https://www.semanticscholar.org/paper/a4b9017d86475d6140949c1136047c6f0d101467',
#    'title': 'Language Identification of Short Text Segments with N-gram Models',
#    'year': 2010,
#    'citationCount': 106,
#    'publicationDate': '2010-05-01'},
#   {'paperId': 'f36aaa5b42c5a533d11c8a8ce31174381a673ac4',
#    'url': 'https://www.semanticscholar.org/paper/f36aaa5b42c5a533d11c8a8ce31174381a673ac4',
#    'title': 'Data Intensive Query Processing for Large RDF Graphs Using Cloud Computing Tools',
#    'year': 2010,
#    'citationCount': 89,
#    'publicationDate': '2010-07-05'},
#   {'paperId': '7560870d43cd7f30bf0d978c45ecda4b9aa6fe75',
#    'url': 'https://www.semanticscholar.org/paper/7560870d43cd7f30bf0d978c45ecda4b9aa6fe75',
#    'title': 'Exploring web scale language models for search query processing',
#    'year': 2010,
#    'citationCount': 74,
#    'publicationDate': '2010-04-26'},
#   {'paperId': '29d0994b813615bc9a93e414d7c327487afdafdd',
#    'url': 'https://www.semanticscholar.org/paper/29d0994b813615bc9a93e414d7c327487afdafdd',
#    'title': 'A Large Scale Ranker-Based System for Search Query Spelling Correction',
#    'year': 2010,
#    'citationCount': 118,
#    'publicationDate': '2010-08-23'},
#   {'paperId': '99b6bb4172d3332d231e4f2b2e288e2f305f0135',
#    'url': 'https://www.semanticscholar.org/paper/99b6bb4172d3332d231e4f2b2e288e2f305f0135',
#    'title': 'Green: a framework for supporting energy-conscious programming using controlled approximation',
#    'year': 2010,
#    'citationCount': 486,
#    'publicationDate': '2010-06-05'},
#   {'paperId': '495eec32b095644b825888dcf8a857cf0f57928f',
#    'url': 'https://www.semanticscholar.org/paper/495eec32b095644b825888dcf8a857cf0f57928f',
#    'title': 'Video Retrieval in Sign Language Videos : How to Model and Compare Signs?',
#    'year': 2010,
#    'citationCount': 1,
#    'publicationDate': None},
#   {'paperId': '5cb674c5a2253c977dea903ce33f7e09a99156dc',
#    'url': 'https://www.semanticscholar.org/paper/5cb674c5a2253c977dea903ce33f7e09a99156dc',
#    'title': 'Phrase-Based Statistical Language Generation Using Graphical Models and Active Learning',
#    'year': 2010,
#    'citationCount': 154,
#    'publicationDate': '2010-07-11'},
#   {'paperId': 'c645d99bf9b3f496a561818b37350d7a1834b92b',
#    'url': 'https://www.semanticscholar.org/paper/c645d99bf9b3f496a561818b37350d7a1834b92b',
#    'title': 'A Language-based Approach to Measuring Scholarly Impact',
#    'year': 2010,
#    'citationCount': 165,
#    'publicationDate': '2010-06-21'},
#   {'paperId': '63dfa69e2b77a042846f5702a443bb60b143a3e7',
#    'url': 'https://www.semanticscholar.org/paper/63dfa69e2b77a042846f5702a443bb60b143a3e7',
#    'title': 'Prosodic attribute model for spoken language identification',
#    'year': 2010,
#    'citationCount': 27,
#    'publicationDate': '2010-03-14'},
#   {'paperId': 'aea0f946e8dcddb65cc2e907456c42453f246a50',
#    'url': 'https://www.semanticscholar.org/paper/aea0f946e8dcddb65cc2e907456c42453f246a50',
#    'title': 'Large scale image annotation: learning\xa0to\xa0rank with\xa0joint word-image embeddings',
#    'year': 2010,
#    'citationCount': 457,
#    'publicationDate': '2010-10-01'},
#   {'paperId': '0d63b530f21705d895080cad3a223ebd94c3e397',
#    'url': 'https://www.semanticscholar.org/paper/0d63b530f21705d895080cad3a223ebd94c3e397',
#    'title': 'The International Urban Energy Balance Models Comparison Project: First Results from Phase 1',
#    'year': 2010,
#    'citationCount': 470,
#    'publicationDate': '2010-06-01'},
#   {'paperId': '3896c98a16b17559f7092dbf1162706bd2a4ce8e',
#    'url': 'https://www.semanticscholar.org/paper/3896c98a16b17559f7092dbf1162706bd2a4ce8e',
#    'title': 'Complementing human judgment of essays written by English language learners with e-rater® scoring',
#    'year': 2010,
#    'citationCount': 105,
#    'publicationDate': '2010-06-15'},
#   {'paperId': 'd9f4c9f419772a290684da72c310a2b2d2e42ffa',
#    'url': 'https://www.semanticscholar.org/paper/d9f4c9f419772a290684da72c310a2b2d2e42ffa',
#    'title': 'Challenges in Combining Projections from Multiple Climate Models',
#    'year': 2010,
#    'citationCount': 1111,
#    'publicationDate': '2010-05-15'},
#   {'paperId': 'f3528f9c7a6d5ff3f6cc4a01bff6271efefd3d34',
#    'url': 'https://www.semanticscholar.org/paper/f3528f9c7a6d5ff3f6cc4a01bff6271efefd3d34',
#    'title': 'T-drive: driving directions based on taxi trajectories',
#    'year': 2010,
#    'citationCount': 1152,
#    'publicationDate': '2010-11-02'},
#   {'paperId': '3a75f171f3445bab975702dfffa9c3153f9d047e',
#    'url': 'https://www.semanticscholar.org/paper/3a75f171f3445bab975702dfffa9c3153f9d047e',
#    'title': 'Toward a Language Modeling Approach for Consumer Review Spam Detection',
#    'year': 2010,
#    'citationCount': 78,
#    'publicationDate': '2010-11-01'},
#   {'paperId': 'a5f8135cf356a80e13241b5b36a5836eaad85fd1',
#    'url': 'https://www.semanticscholar.org/paper/a5f8135cf356a80e13241b5b36a5836eaad85fd1',
#    'title': 'Improved neural network based language modelling and adaptation',
#    'year': 2010,
#    'citationCount': 87,
#    'publicationDate': '2010-09-30'},
#   {'paperId': 'ebe45e659c511d8f52d935a73c1386b70ee7d583',
#    'url': 'https://www.semanticscholar.org/paper/ebe45e659c511d8f52d935a73c1386b70ee7d583',
#    'title': 'Focused Retrieval and Evaluation, 8th International Workshop of the Initiative for the Evaluation of XML Retrieval, INEX 2009, Brisbane, Australia, December 7-9, 2009, Revised and Selected Papers',
#    'year': 2010,
#    'citationCount': 49,
#    'publicationDate': None},
#   {'paperId': '308f33159ee71c1c884c0555cd0d6e11e2899f6e',
#    'url': 'https://www.semanticscholar.org/paper/308f33159ee71c1c884c0555cd0d6e11e2899f6e',
#    'title': 'Sentence Correction Incorporating Relative Position and Parse Template Language Models',
#    'year': 2010,
#    'citationCount': 55,
#    'publicationDate': '2010-08-01'},
#   {'paperId': '5d67baff261aec11bbbe47800711032a8f283965',
#    'url': 'https://www.semanticscholar.org/paper/5d67baff261aec11bbbe47800711032a8f283965',
#    'title': 'A Cascade Method for Detecting Hedges and their Scope in Natural Language Text',
#    'year': 2010,
#    'citationCount': 60,
#    'publicationDate': '2010-07-15'},
#   {'paperId': 'a0acc87b467796f5970429b80e4b4278afcc1854',
#    'url': 'https://www.semanticscholar.org/paper/a0acc87b467796f5970429b80e4b4278afcc1854',
#    'title': 'A Context-Dependent Supervised Learning Approach to Sentiment Detection in Large Textual Databases',
#    'year': 2010,
#    'citationCount': 37,
#    'publicationDate': '2010-09-09'},
#   {'paperId': '6af2ab2f499c18743c3137b04034ddb1688fc33c',
#    'url': 'https://www.semanticscholar.org/paper/6af2ab2f499c18743c3137b04034ddb1688fc33c',
#    'title': 'Semantic Processing of Legal Texts: Where the Language of Law Meets the Law of Language',
#    'year': 2010,
#    'citationCount': 60,
#    'publicationDate': None},
#   {'paperId': 'af3fd9655dca2781c6864f39a0daf730d0eee55b',
#    'url': 'https://www.semanticscholar.org/paper/af3fd9655dca2781c6864f39a0daf730d0eee55b',
#    'title': 'Rapid bootstrapping of five eastern european languages using the rapid language adaptation toolkit',
#    'year': 2010,
#    'citationCount': 40,
#    'publicationDate': None},
#   {'paperId': '8a3c09414e8037dcf61a243af3f1c71e5c9a9ea8',
#    'url': 'https://www.semanticscholar.org/paper/8a3c09414e8037dcf61a243af3f1c71e5c9a9ea8',
#    'title': 'HaLoop',
#    'year': 2010,
#    'citationCount': 896,
#    'publicationDate': '2010-09-01'},
#   {'paperId': '460757b33fb888e90f2b54f60d793b05d76c6ff7',
#    'url': 'https://www.semanticscholar.org/paper/460757b33fb888e90f2b54f60d793b05d76c6ff7',
#    'title': 'Hierarchical Bayesian Language Models for Conversational Speech Recognition',
#    'year': 2010,
#    'citationCount': 38,
#    'publicationDate': '2010-11-01'},
#   {'paperId': 'f944aefaf6ed7e2a569fdd1ef94a04092aa06680',
#    'url': 'https://www.semanticscholar.org/paper/f944aefaf6ed7e2a569fdd1ef94a04092aa06680',
#    'title': 'Discriminative language modeling using simulated ASR errors',
#    'year': 2010,
#    'citationCount': 38,
#    'publicationDate': None},
#   {'paperId': 'b80fee5432b99cc65b6a185680ff1d432cc8d529',
#    'url': 'https://www.semanticscholar.org/paper/b80fee5432b99cc65b6a185680ff1d432cc8d529',
#    'title': 'Integrating natural language and program structure information to improve software search and exploration',
#    'year': 2010,
#    'citationCount': 54,
#    'publicationDate': None},
#   {'paperId': 'd8f16d74a2497fc6624cdc93a7601c2dcc531b04',
#    'url': 'https://www.semanticscholar.org/paper/d8f16d74a2497fc6624cdc93a7601c2dcc531b04',
#    'title': 'LIMA : A Multilingual Framework for Linguistic Analysis and Linguistic Resources Development and Evaluation',
#    'year': 2010,
#    'citationCount': 50,
#    'publicationDate': '2010-05-01'},
#   {'paperId': '97c4154e9c02eaa99f518085b92ca911219ffc3a',
#    'url': 'https://www.semanticscholar.org/paper/97c4154e9c02eaa99f518085b92ca911219ffc3a',
#    'title': 'An empirical generative framework for computational modeling of language acquisition.',
#    'year': 2010,
#    'citationCount': 58,
#    'publicationDate': '2010-06-01'},
#   {'paperId': 'f095f107030a072341feacef659d9dfec31f53e4',
#    'url': 'https://www.semanticscholar.org/paper/f095f107030a072341feacef659d9dfec31f53e4',
#    'title': 'Structural and fluid analysis for large scale PEPA models - with applications to content adaptation systems',
#    'year': 2010,
#    'citationCount': 27,
#    'publicationDate': '2010-06-28'},
#   {'paperId': '61b296922d985c75369795e97aa4045ec0d3f761',
#    'url': 'https://www.semanticscholar.org/paper/61b296922d985c75369795e97aa4045ec0d3f761',
#    'title': 'Chapter 14. Re-thinking the bilingual interactive-activation model from a developmental perspective (BIA-d)',
#    'year': 2010,
#    'citationCount': 141,
#    'publicationDate': '2010-12-15'},
#   {'paperId': 'c65110b765b47f0b2c06fc10ed4f367a343b6690',
#    'url': 'https://www.semanticscholar.org/paper/c65110b765b47f0b2c06fc10ed4f367a343b6690',
#    'title': 'Automating the Mean-Field Method for Large Dynamic Gossip Networks',
#    'year': 2010,
#    'citationCount': 27,
#    'publicationDate': '2010-09-15'},
#   {'paperId': 'e223dfd72bc42820723d6ba7a6d62396b5deb68a',
#    'url': 'https://www.semanticscholar.org/paper/e223dfd72bc42820723d6ba7a6d62396b5deb68a',
#    'title': 'Methods to Improve Gaussian Mixture Model for Language Identification',
#    'year': 2010,
#    'citationCount': 6,
#    'publicationDate': '2010-03-13'},
#   {'paperId': '18a5114a0be92ffcdce429cbd5b406c2e9a2992b',
#    'url': 'https://www.semanticscholar.org/paper/18a5114a0be92ffcdce429cbd5b406c2e9a2992b',
#    'title': 'VeriML: typed computation of logical terms inside a language with effects',
#    'year': 2010,
#    'citationCount': 46,
#    'publicationDate': '2010-09-27'},
#   {'paperId': '75db1aa3d2bbfef6c0739df2edfefbd6320a8837',
#    'url': 'https://www.semanticscholar.org/paper/75db1aa3d2bbfef6c0739df2edfefbd6320a8837',
#    'title': 'Distributed QoS Evaluation for Real-World Web Services',
#    'year': 2010,
#    'citationCount': 369,
#    'publicationDate': '2010-07-05'},
#   {'paperId': '4a4b5ae5793696b861aa009932e7a121d36ad67a',
#    'url': 'https://www.semanticscholar.org/paper/4a4b5ae5793696b861aa009932e7a121d36ad67a',
#    'title': 'What helps where – and why? Semantic relatedness for knowledge transfer',
#    'year': 2010,
#    'citationCount': 315,
#    'publicationDate': '2010-06-13'},
#   {'paperId': '450fa6f18a77728ba09d1a2fecc967beec557109',
#    'url': 'https://www.semanticscholar.org/paper/450fa6f18a77728ba09d1a2fecc967beec557109',
#    'title': 'Large-Scale Support Vector Learning with Structural Kernels',
#    'year': 2010,
#    'citationCount': 25,
#    'publicationDate': '2010-09-20'},
#   {'paperId': '192d1e814012dd98d1a6c701ff26c8e9c469eebc',
#    'url': 'https://www.semanticscholar.org/paper/192d1e814012dd98d1a6c701ff26c8e9c469eebc',
#    'title': 'Evaluation of Kermeta for solving graph-based problems',
#    'year': 2010,
#    'citationCount': 27,
# ...
#    'title': 'Utveckling av verktyg för användardriven processmodellering',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': '315a6ff792f13694d36daeb03d2410aa08500d8a',
#    'url': 'https://www.semanticscholar.org/paper/315a6ff792f13694d36daeb03d2410aa08500d8a',
#    'title': 'Selecting Groups of Audio Features by Statistical Tests and the Group Lasso',
#    'year': 2010,
#    'citationCount': 2,
#    'publicationDate': None},
#   {'paperId': 'fb1492e800233bc1b49798710c809293c6e583f7',
#    'url': 'https://www.semanticscholar.org/paper/fb1492e800233bc1b49798710c809293c6e583f7',
#    'title': 'Towards a Better Change Impact Analysis in Architecture Description Languages',
#    'year': 2010,
#    'citationCount': 2,
#    'publicationDate': '2010-07-22'},
#   {'paperId': 'ea9d2a2b4ce11aaf85136840c65f3bc9c03ab649',
#    'url': 'https://www.semanticscholar.org/paper/ea9d2a2b4ce11aaf85136840c65f3bc9c03ab649',
#    'title': 'Understanding the difficulty of training deep feedforward neural networks',
#    'year': 2010,
#    'citationCount': 17031,
#    'publicationDate': '2010-03-31'},
#   {'paperId': '960dcf1b4585fde8c3a6c6e6bf34cef6b5596d0c',
#    'url': 'https://www.semanticscholar.org/paper/960dcf1b4585fde8c3a6c6e6bf34cef6b5596d0c',
#    'title': 'CloudAnalyst: A CloudSim-Based Visual Modeller for Analysing Cloud Computing Environments and Applications',
#    'year': 2010,
#    'citationCount': 702,
#    'publicationDate': '2010-04-20'},
#   {'paperId': '3981fc3d9d419abe48a5188cd17db4fefcfde80b',
#    'url': 'https://www.semanticscholar.org/paper/3981fc3d9d419abe48a5188cd17db4fefcfde80b',
#    'title': 'Validation of Advanced Microwave Scanning Radiometer Soil Moisture Products',
#    'year': 2010,
#    'citationCount': 549,
#    'publicationDate': '2010-06-28'},
#   {'paperId': '716d77c56be819832fa01900fcf44a0967f7e398',
#    'url': 'https://www.semanticscholar.org/paper/716d77c56be819832fa01900fcf44a0967f7e398',
#    'title': 'Discovering graphical Granger causality using the truncating lasso penalty',
#    'year': 2010,
#    'citationCount': 211,
#    'publicationDate': '2010-07-03'},
#   {'paperId': 'c97432c9640d0bb825c4c3c36a770077f8e53161',
#    'url': 'https://www.semanticscholar.org/paper/c97432c9640d0bb825c4c3c36a770077f8e53161',
#    'title': 'Unsupervised Object Discovery: A Comparison',
#    'year': 2010,
#    'citationCount': 219,
#    'publicationDate': '2010-06-01'},
#   {'paperId': '9b597eb6115e02c6d827f1a02cb6cacbb6f1a8e2',
#    'url': 'https://www.semanticscholar.org/paper/9b597eb6115e02c6d827f1a02cb6cacbb6f1a8e2',
#    'title': 'Learning Bayesian networks by hill climbing: efficient methods based on progressive restriction of the neighborhood',
#    'year': 2010,
#    'citationCount': 223,
#    'publicationDate': None},
#   {'paperId': 'b5e96c001697c5170c5ce742abd4f4daf86ad20c',
#    'url': 'https://www.semanticscholar.org/paper/b5e96c001697c5170c5ce742abd4f4daf86ad20c',
#    'title': 'New filtering approaches for phishing email',
#    'year': 2010,
#    'citationCount': 174,
#    'publicationDate': None},
#   {'paperId': 'de9f790fd0289fb4282701186dbe12e3345c6a6c',
#    'url': 'https://www.semanticscholar.org/paper/de9f790fd0289fb4282701186dbe12e3345c6a6c',
#    'title': 'Visual syntax does matter: improving the cognitive effectiveness of the i* visual notation',
#    'year': 2010,
#    'citationCount': 138,
#    'publicationDate': '2010-06-01'},
#   {'paperId': 'be5a109eb510e106e49747d29a5bfbd6e1522cbb',
#    'url': 'https://www.semanticscholar.org/paper/be5a109eb510e106e49747d29a5bfbd6e1522cbb',
#    'title': 'The challenge of conceptual modeling for product–service systems: status-quo and perspectives for reference models and modeling languages',
#    'year': 2010,
#    'citationCount': 163,
#    'publicationDate': None},
#   {'paperId': '47f1919a40f30ff1552d23ade318b71129d7980c',
#    'url': 'https://www.semanticscholar.org/paper/47f1919a40f30ff1552d23ade318b71129d7980c',
#    'title': 'Analysis of deformable image registration accuracy using computational modeling.',
#    'year': 2010,
#    'citationCount': 122,
#    'publicationDate': '2010-03-01'},
#   {'paperId': '77b919c4f4f37415d8f1019b1b04191d46de426c',
#    'url': 'https://www.semanticscholar.org/paper/77b919c4f4f37415d8f1019b1b04191d46de426c',
#    'title': 'Fast query execution for retrieval models based on path-constrained random walks',
#    'year': 2010,
#    'citationCount': 103,
#    'publicationDate': '2010-07-25'},
#   {'paperId': '118d0ca1d7783db5b7e37c1454629ca8be48662a',
#    'url': 'https://www.semanticscholar.org/paper/118d0ca1d7783db5b7e37c1454629ca8be48662a',
#    'title': 'Computational approaches to 3D modeling of RNA',
#    'year': 2010,
#    'citationCount': 113,
#    'publicationDate': '2010-06-15'},
#   {'paperId': '3da5cef9d09250613ed1658fc6349885fd385427',
#    'url': 'https://www.semanticscholar.org/paper/3da5cef9d09250613ed1658fc6349885fd385427',
#    'title': 'Process mining : conformance and extension',
#    'year': 2010,
#    'citationCount': 87,
#    'publicationDate': None},
#   {'paperId': 'fe2448d42419f1fbf6ae99d2740d9edfe4a7bb7e',
#    'url': 'https://www.semanticscholar.org/paper/fe2448d42419f1fbf6ae99d2740d9edfe4a7bb7e',
#    'title': 'MemSafe: Ensuring the Spatial and Temporal Memory Safety of C at Runtime',
#    'year': 2010,
#    'citationCount': 91,
#    'publicationDate': '2010-09-12'},
#   {'paperId': 'cd1606f4cac44ee1f29b403520180fe58e8ee7d4',
#    'url': 'https://www.semanticscholar.org/paper/cd1606f4cac44ee1f29b403520180fe58e8ee7d4',
#    'title': 'SysML modeling of off-the-shelf-option acquisition for risk mitigation in military programs',
#    'year': 2010,
#    'citationCount': 82,
#    'publicationDate': '2010-02-01'},
#   {'paperId': '6d03a2b588bf501ac141b725d98df472590d85f5',
#    'url': 'https://www.semanticscholar.org/paper/6d03a2b588bf501ac141b725d98df472590d85f5',
#    'title': 'Enabling active storage on parallel I/O software stacks',
#    'year': 2010,
#    'citationCount': 77,
#    'publicationDate': '2010-05-03'},
#   {'paperId': 'd13626b0650676dc4886ebe3d4fd67065676d28a',
#    'url': 'https://www.semanticscholar.org/paper/d13626b0650676dc4886ebe3d4fd67065676d28a',
#    'title': 'A Comparison of Six UML-Based Languages for Software Process Modeling',
#    'year': 2010,
#    'citationCount': 91,
#    'publicationDate': '2010-09-01'},
#   {'paperId': '0fae6d70a155e78592e65c1f589274bfee64f323',
#    'url': 'https://www.semanticscholar.org/paper/0fae6d70a155e78592e65c1f589274bfee64f323',
#    'title': 'Path Problems in Networks',
#    'year': 2010,
#    'citationCount': 56,
#    'publicationDate': '2010-01-01'},
#   {'paperId': '4c78ae01b415e8a471cb3eb93aaf5838c35fff5f',
#    'url': 'https://www.semanticscholar.org/paper/4c78ae01b415e8a471cb3eb93aaf5838c35fff5f',
#    'title': 'Open-graphs and monoidal theories†',
#    'year': 2010,
#    'citationCount': 54,
#    'publicationDate': '2010-11-18'},
#   {'paperId': 'e6525edb60329d28ad209a50dd521db256c6ad95',
#    'url': 'https://www.semanticscholar.org/paper/e6525edb60329d28ad209a50dd521db256c6ad95',
#    'title': 'Towards an ontological foundation of discrete event simulation',
#    'year': 2010,
#    'citationCount': 48,
#    'publicationDate': '2010-12-05'},
#   {'paperId': '142e563312184c48504260cc5552fd9a4cbd711e',
#    'url': 'https://www.semanticscholar.org/paper/142e563312184c48504260cc5552fd9a4cbd711e',
#    'title': 'An attribute-based authorization policy framework with dynamic conflict resolution',
#    'year': 2010,
#    'citationCount': 50,
#    'publicationDate': '2010-04-13'},
#   {'paperId': '197785c9c602d52c94ce279494dcad1bdccc3161',
#    'url': 'https://www.semanticscholar.org/paper/197785c9c602d52c94ce279494dcad1bdccc3161',
#    'title': 'Script-Based Generation of Dynamic Testbeds for SOA',
#    'year': 2010,
#    'citationCount': 50,
#    'publicationDate': '2010-07-05'},
#   {'paperId': 'b5cf4ed76ba4e106348f6a4a0939bae6c7ed40ad',
#    'url': 'https://www.semanticscholar.org/paper/b5cf4ed76ba4e106348f6a4a0939bae6c7ed40ad',
#    'title': 'A generative theory of relevance',
#    'year': 2010,
#    'citationCount': 41,
#    'publicationDate': '2010-12-01'},
#   {'paperId': 'c5bcb690b0aa85ad0a5fd7e7aa4b8c468cd8c69a',
#    'url': 'https://www.semanticscholar.org/paper/c5bcb690b0aa85ad0a5fd7e7aa4b8c468cd8c69a',
#    'title': 'Discriminative training based on an integrated view of MPE and MMI in margin and error space',
#    'year': 2010,
#    'citationCount': 43,
#    'publicationDate': '2010-03-14'},
#   {'paperId': '5527cbcc21d6a65c54cf08b008b4886069d99d4e',
#    'url': 'https://www.semanticscholar.org/paper/5527cbcc21d6a65c54cf08b008b4886069d99d4e',
#    'title': 'Lean-Agile Acceptance Test-Driven Development: Better Software Through Collaboration',
#    'year': 2010,
#    'citationCount': 39,
#    'publicationDate': '2010-12-22'},
#   {'paperId': 'b541a14a5bbdce1826f34608025f898794377d67',
#    'url': 'https://www.semanticscholar.org/paper/b541a14a5bbdce1826f34608025f898794377d67',
#    'title': 'A DSL-Based Approach to Software Development and Deployment on Cloud',
#    'year': 2010,
#    'citationCount': 41,
#    'publicationDate': '2010-04-20'},
#   {'paperId': 'f2616595bf6530aa6626396c6166c5902396e4ca',
#    'url': 'https://www.semanticscholar.org/paper/f2616595bf6530aa6626396c6166c5902396e4ca',
#    'title': 'An approach towards context-sensitive and user-adapted access to heterogeneous data sources, illustrated in the television domain',
#    'year': 2010,
#    'citationCount': 38,
#    'publicationDate': None},
#   {'paperId': '23c80dd819d51037f0760425c08705bfede5cbb5',
#    'url': 'https://www.semanticscholar.org/paper/23c80dd819d51037f0760425c08705bfede5cbb5',
#    'title': 'Analyzing the behavior of event processing applications',
#    'year': 2010,
#    'citationCount': 22,
#    'publicationDate': '2010-07-12'},
#   {'paperId': '778263b2e211d23da32466f10b49f53c842f5383',
#    'url': 'https://www.semanticscholar.org/paper/778263b2e211d23da32466f10b49f53c842f5383',
#    'title': 'Challenges in Cross‐National Data Collection',
#    'year': 2010,
#    'citationCount': 25,
#    'publicationDate': '2010-05-05'},
#   {'paperId': 'a44fd8c3dd67ed98032a7a7ac0a130d9e27f7b7f',
#    'url': 'https://www.semanticscholar.org/paper/a44fd8c3dd67ed98032a7a7ac0a130d9e27f7b7f',
#    'title': 'The Key to Adventure Game Design: Insight and Sense-making',
#    'year': 2010,
#    'citationCount': 14,
#    'publicationDate': '2010-10-01'},
#   {'paperId': '95266b19cd006a61dde4b80654be4956c9e54837',
#    'url': 'https://www.semanticscholar.org/paper/95266b19cd006a61dde4b80654be4956c9e54837',
#    'title': 'Core Concepts For Engineering Literacy: The Interrelationships Among Stem Disciplines',
#    'year': 2010,
#    'citationCount': 15,
#    'publicationDate': '2010-06-20'},
#   {'paperId': 'ef041c77303de91baf765d2a9d432aade7787a1a',
#    'url': 'https://www.semanticscholar.org/paper/ef041c77303de91baf765d2a9d432aade7787a1a',
#    'title': 'Higher-Order Attribute Semantics of Flat Languages',
#    'year': 2010,
#    'citationCount': 13,
#    'publicationDate': '2010-11-17'},
#   {'paperId': 'fc2ad76c6e483c2d8a389cf542b8ce2d31031ab4',
#    'url': 'https://www.semanticscholar.org/paper/fc2ad76c6e483c2d8a389cf542b8ce2d31031ab4',
#    'title': 'A scalable locality-aware adaptive work-stealing scheduler for multi-core task parallelism',
#    'year': 2010,
#    'citationCount': 9,
#    'publicationDate': None},
#   {'paperId': 'af0ed68b7f1108637c4613d8eaf723ee45b343d1',
#    'url': 'https://www.semanticscholar.org/paper/af0ed68b7f1108637c4613d8eaf723ee45b343d1',
#    'title': 'Robust machine translation for multi-domain tasks',
#    'year': 2010,
#    'citationCount': 5,
#    'publicationDate': None},
#   {'paperId': '71d544c196e4dfbf2abd8be731280ad83b43ebfc',
#    'url': 'https://www.semanticscholar.org/paper/71d544c196e4dfbf2abd8be731280ad83b43ebfc',
#    'title': "Copyright © 2010 Livermore Software Technology Corp. ( 11th Int'l LS-DYNA® Users Conf.-Dearborn, MI, USA-June 6-8, 2010)",
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': '92fbed4d049d48a7f8c7bfcaf7082273062f5ae5',
#    'url': 'https://www.semanticscholar.org/paper/92fbed4d049d48a7f8c7bfcaf7082273062f5ae5',
#    'title': 'On run-time exploitation of concurrency',
#    'year': 2010,
#    'citationCount': 4,
#    'publicationDate': '2010-04-23'},
#   {'paperId': '8f190ba220217f5b7c795a890a72714af250b886',
#    'url': 'https://www.semanticscholar.org/paper/8f190ba220217f5b7c795a890a72714af250b886',
#    'title': 'Technology and Recent Development of XML Web Services',
#    'year': 2010,
#    'citationCount': 4,
#    'publicationDate': None},
#   {'paperId': 'a9d9bc0091bad9d297ce0a00829e41b76e860a81',
#    'url': 'https://www.semanticscholar.org/paper/a9d9bc0091bad9d297ce0a00829e41b76e860a81',
#    'title': 'Creativity: Simulation, stimulation, and studies',
#    'year': 2010,
#    'citationCount': 4,
#    'publicationDate': '2010-04-26'},
#   {'paperId': '350195e6e7ef68db1ee1a36235c10ed5f596f175',
#    'url': 'https://www.semanticscholar.org/paper/350195e6e7ef68db1ee1a36235c10ed5f596f175',
#    'title': 'Structural, syntactic, and statistical pattern recognition : joint IAPR international workshop, SSPR & SPR 2010 : Cesme, Izmir, Turkey, August 18 - 20, 2010 : proceedings',
#    'year': 2010,
#    'citationCount': 1,
#    'publicationDate': None},
#   {'paperId': 'dd2e69ef78ea63371a1331e0d66b32792e053931',
#    'url': 'https://www.semanticscholar.org/paper/dd2e69ef78ea63371a1331e0d66b32792e053931',
#    'title': 'University ’ s repository of research publications and other research outputs Open educational resources in Europe : A triptych of actions to support participation in higher education Conference Item',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': '14f20fba4ff93ade144cea0d870f39880904e8e1',
#    'url': 'https://www.semanticscholar.org/paper/14f20fba4ff93ade144cea0d870f39880904e8e1',
#    'title': 'A Business Process Modeling Approach',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': 'd9d31e2fbeb9dd5c389b4fb2a979a99615fe6168',
#    'url': 'https://www.semanticscholar.org/paper/d9d31e2fbeb9dd5c389b4fb2a979a99615fe6168',
#    'title': 'Robust Speech Based Emotion Analysis for Driver Assistance System',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': '4bc45d8f68da267e19017d3783fc73e0ac5309a8',
#    'url': 'https://www.semanticscholar.org/paper/4bc45d8f68da267e19017d3783fc73e0ac5309a8',
#    'title': 'Beyond short units in speech recognition: a syllable centric and prominence based approach',
#    'year': 2010,
#    'citationCount': 1,
#    'publicationDate': '2010-11-30'},
#   {'paperId': '4522fc5d0f6b14ddb0225311e23041058329a262',
#    'url': 'https://www.semanticscholar.org/paper/4522fc5d0f6b14ddb0225311e23041058329a262',
#    'title': "Copyright © 2010 Livermore Software Technology Corp. ( 11th Int'l LS-DYNA® Users Conf.-Dearborn, MI, USA-June 6-8, 2010)",
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': '392100ab704b179e16203369207049f4cd898038',
#    'url': 'https://www.semanticscholar.org/paper/392100ab704b179e16203369207049f4cd898038',
#    'title': 'Modelling Static Networks in Bioinformatics Applications Using Advanced Computing',
#    'year': 2010,
#    'citationCount': 1,
#    'publicationDate': '2010-10-01'},
#   {'paperId': 'db172292d8a632c390410786f7e594af1a31caef',
#    'url': 'https://www.semanticscholar.org/paper/db172292d8a632c390410786f7e594af1a31caef',
#    'title': 'Improving FPGA application development via strategic exploration, performance prediction, and tradeoff analysis',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': 'bfe80f3e0cfb5d29bc4a937a5c56aeb7447878e3',
#    'url': 'https://www.semanticscholar.org/paper/bfe80f3e0cfb5d29bc4a937a5c56aeb7447878e3',
#    'title': 'Enterprise Systems Modifiability Analysis',
#    'year': 2010,
#    'citationCount': 0,
#    'publicationDate': None},
#   {'paperId': '9677071734f265d69e575df1984dd3bb3c875650',
#    'url': 'https://www.semanticscholar.org/paper/9677071734f265d69e575df1984dd3bb3c875650',
#    'title': 'Symposium 7: Current challenges in learning design and pedagogical patterns research',
#    'year': 2010,
#    'citationCount': 1,
#    'publicationDate': '2010-05-03'}]]

# %%
create_scatter_plot(papers)
# Out:
# [{'date': datetime.datetime(2017, 6, 12, 0, 0),
#   'citations': 114406,
#   'title': 'Attention is All you Need'},
#  {'date': datetime.datetime(2018, 2, 16, 0, 0),
#   'citations': 999,
#   'title': 'Diversity is All You Need: Learning Skills without a Reward Function'},
#  {'date': datetime.datetime(2020, 8, 23, 0, 0),
#   'citations': 652,
#   'title': 'A Lip Sync Expert Is All You Need for Speech to Lip Generation In the Wild'},
#  {'date': datetime.datetime(2020, 4, 28, 0, 0),
#   'citations': 715,
#   'title': 'Image Augmentation Is All You Need: Regularizing Deep Reinforcement Learning from Pixels'},
#  {'date': datetime.datetime(2020, 3, 25, 0, 0),
#   'citations': 832,
#   'title': 'Rethinking Few-Shot Image Classification: a Good Embedding Is All You Need?'},
#  {'date': datetime.datetime(2024, 11, 4, 0, 0),
#   'citations': 62,
#   'title': 'Protein generation with evolutionary diffusion: sequence is all you need'},
#  {'date': datetime.datetime(2024, 9, 27, 0, 0),
#   'citations': 44,
#   'title': 'Emu3: Next-Token Prediction is All You Need'},
#  {'date': datetime.datetime(2024, 2, 3, 0, 0),
#   'citations': 40,
#   'title': 'More Agents Is All You Need'},
#  {'date': datetime.datetime(2021, 10, 12, 0, 0),
#   'citations': 350,
#   'title': 'Open-Set Recognition: A Good Closed-Set Classifier is All You Need'},
#  {'date': datetime.datetime(2024, 3, 26, 0, 0),
#   'citations': 19,
#   'title': 'COIG-CQIA: Quality is All You Need for Chinese Instruction Fine-tuning'},
#  {'date': datetime.datetime(2020, 10, 25, 0, 0),
#   'citations': 473,
#   'title': 'Attention Is All You Need In Speech Separation'},
#  {'date': datetime.datetime(2024, 4, 12, 0, 0),
#   'citations': 16,
#   'title': 'Code Search Is All You Need? Improving Code Suggestions with Code Search'},
#  {'date': datetime.datetime(2023, 5, 23, 0, 0),
#   'citations': 143,
#   'title': 'Text Is All You Need: Learning Language Representations for Sequential Recommendation'},
#  {'date': datetime.datetime(2022, 2, 28, 0, 0),
#   'citations': 211,
#   'title': 'Filter-enhanced MLP is All You Need for Sequential Recommendation'},
#  {'date': datetime.datetime(2020, 4, 3, 0, 0),
#   'citations': 269,
#   'title': 'Channel Attention Is All You Need for Video Frame Interpolation'},
#  {'date': datetime.datetime(2020, 7, 16, 0, 0),
#   'citations': 365,
#   'title': 'Hopfield Networks is All You Need'},
#  {'date': datetime.datetime(2021, 2, 9, 0, 0),
#   'citations': 1763,
#   'title': 'Is Space-Time Attention All You Need for Video Understanding?'},
#  {'date': datetime.datetime(2023, 11, 22, 0, 0),
#   'citations': 89,
#   'title': 'Attention is all you need: utilizing attention in AI-enabled drug discovery'},
#  {'date': datetime.datetime(2022, 3, 31, 0, 0),
#   'citations': 118,
#   'title': 'TransGeo: Transformer Is All You Need for Cross-view Image Geo-localization'},
#  {'date': datetime.datetime(2024, 4, 1, 0, 0),
#   'citations': 1,
#   'title': 'Positioning is All You Need'},
#  {'date': datetime.datetime(2023, 6, 3, 0, 0),
#   'citations': 61,
#   'title': 'Prompting Is All You Need: Automated Android Bug Replay with Large Language Models'},
#  {'date': datetime.datetime(2022, 3, 14, 0, 0),
#   'citations': 185,
#   'title': 'Respecting causality is all you need for training physics-informed neural networks'},
#  {'date': datetime.datetime(2022, 5, 25, 0, 0),
#   'citations': 168,
#   'title': 'Pretraining is All You Need for Image-to-Image Translation'},
#  {'date': datetime.datetime(2023, 2, 18, 0, 0),
#   'citations': 38,
#   'title': 'Temporal Interpolation is all You Need for Dynamic Neural Radiance Fields'},
#  {'date': datetime.datetime(2023, 4, 5, 0, 0),
#   'citations': 32,
#   'title': 'Effective control of two-dimensional Rayleigh-Bénard convection: invariant multi-agent reinforcement learning is all you need'},
#  {'date': datetime.datetime(2023, 2, 6, 0, 0),
#   'citations': 32,
#   'title': 'Rethinking Out-of-distribution (OOD) Detection: Masked Image Modeling is All You Need'},
#  {'date': datetime.datetime(2023, 7, 13, 0, 0),
#   'citations': 23,
#   'title': 'Copy is All You Need'},
#  {'date': datetime.datetime(2020, 3, 10, 0, 0),
#   'citations': 253,
#   'title': 'ReZero is All You Need: Fast Convergence at Large Depth'},
#  {'date': datetime.datetime(2020, 2, 3, 0, 0),
#   'citations': 257,
#   'title': 'Proving the Lottery Ticket Hypothesis: Pruning is All You Need'},
#  {'date': datetime.datetime(2021, 7, 13, 0, 0),
#   'citations': 1314,
#   'title': 'Per-Pixel Classification is Not All You Need for Semantic Segmentation'},
#  {'date': datetime.datetime(2024, 10, 24, 0, 0),
#   'citations': 0,
#   'title': 'Intention Is All You Need'},
#  {'date': datetime.datetime(2024, 12, 9, 0, 0),
#   'citations': 0,
#   'title': '[MASK] is All You Need'},
#  {'date': datetime.datetime(2023, 9, 13, 0, 0),
#   'citations': 22,
#   'title': 'Pretraining on the Test Set Is All You Need'},
#  {'date': datetime.datetime(2023, 4, 23, 0, 0),
#   'citations': 21,
#   'title': 'Feedback is all you need: from ChatGPT to autonomous driving'},
#  {'date': datetime.datetime(2023, 10, 29, 0, 0),
#   'citations': 20,
#   'title': 'Label Poisoning is All You Need'},
#  {'date': datetime.datetime(2023, 6, 20, 0, 0),
#   'citations': 16,
#   'title': 'Randomized Quantization is All You Need for Differential Privacy in Federated Learning'},
#  {'date': datetime.datetime(2020, 12, 11, 0, 0),
#   'citations': 172,
#   'title': 'Few-Shot Segmentation Without Meta-Learning: A Good Transductive Inference Is All You Need?'},
#  {'date': datetime.datetime(2023, 8, 29, 0, 0),
#   'citations': 16,
#   'title': 'Vector Search with OpenAI Embeddings: Lucene Is All You Need'},
#  {'date': datetime.datetime(2019, 11, 6, 0, 0),
#   'citations': 346,
#   'title': 'Fast Transformer Decoding: One Write-Head is All You Need'},
#  {'date': datetime.datetime(2023, 11, 25, 0, 0),
#   'citations': 11,
#   'title': 'Adapter is All You Need for Tuning Visual Tasks'},
#  {'date': datetime.datetime(2023, 4, 13, 0, 0),
#   'citations': 11,
#   'title': 'Probe microscopy is all you need'},
#  {'date': datetime.datetime(2022, 10, 13, 0, 0),
#   'citations': 39,
#   'title': 'H2RBox: Horizontal Box Annotation is All You Need for Oriented Object Detection'},
#  {'date': datetime.datetime(2022, 3, 28, 0, 0),
#   'citations': 37,
#   'title': 'Neural Vocoder is All You Need for Speech Super-resolution'},
#  {'date': datetime.datetime(2023, 6, 16, 0, 0),
#   'citations': 4,
#   'title': 'Gradient is All You Need?'},
#  {'date': datetime.datetime(2022, 5, 20, 0, 0),
#   'citations': 34,
#   'title': 'Sampling Is All You Need on Modeling Long-Term User Behaviors for CTR Prediction'},
#  {'date': datetime.datetime(2022, 12, 18, 0, 0),
#   'citations': 29,
#   'title': 'Fine-Tuning Is All You Need to Mitigate Backdoor Attacks'},
#  {'date': datetime.datetime(2021, 9, 16, 0, 0),
#   'citations': 75,
#   'title': 'Torch.manual_seed(3407) is all you need: On the influence of random seeds in deep learning architectures for computer vision'},
#  {'date': datetime.datetime(2020, 6, 30, 0, 0),
#   'citations': 114,
#   'title': 'Data Movement Is All You Need: A Case Study on Optimizing Transformers'},
#  {'date': datetime.datetime(2022, 8, 23, 0, 0),
#   'citations': 24,
#   'title': 'Extending nnU-Net is all you need'},
#  {'date': datetime.datetime(2021, 4, 18, 0, 0),
#   'citations': 84,
#   'title': 'Cross-Attention is All You Need: Adapting Pretrained Transformers for Machine Translation'},
#  {'date': datetime.datetime(2022, 5, 30, 0, 0),
#   'citations': 17,
#   'title': 'GMML is All You Need'},
#  {'date': datetime.datetime(2020, 6, 1, 0, 0),
#   'citations': 82,
#   'title': 'Logarithmic Pruning is All You Need'},
#  {'date': datetime.datetime(2019, 11, 28, 0, 0),
#   'citations': 129,
#   'title': 'ASR is All You Need: Cross-Modal Distillation for Lip Reading'},
#  {'date': datetime.datetime(2023, 9, 11, 0, 0),
#   'citations': 356,
#   'title': 'Textbooks Are All You Need II: phi-1.5 technical report'},
#  {'date': datetime.datetime(2021, 11, 18, 0, 0),
#   'citations': 43,
#   'title': 'Perceiving and Modeling Density is All You Need for Image Dehazing'},
#  {'date': datetime.datetime(2021, 5, 18, 0, 0),
#   'citations': 42,
#   'title': 'Value Function is All You Need: A Unified Learning Framework for Ride Hailing Platforms'},
#  {'date': datetime.datetime(2021, 8, 3, 0, 0),
#   'citations': 47,
#   'title': 'SphereFace2: Binary Classification is All You Need for Deep Face Recognition'},
#  {'date': datetime.datetime(2021, 7, 13, 0, 0),
#   'citations': 37,
#   'title': 'A Configurable Multilingual Model is All You Need to Recognize All Languages'},
#  {'date': datetime.datetime(2020, 11, 20, 0, 0),
#   'citations': 56,
#   'title': 'A Reputation Mechanism Is All You Need: Collaborative Fairness and Adversarial Robustness in Federated Learning'},
#  {'date': datetime.datetime(2020, 4, 21, 0, 0),
#   'citations': 77,
#   'title': 'Empathy Is All You Need: How a Conversational Agent Should Respond to Verbal Abuse'},
#  {'date': datetime.datetime(2019, 2, 3, 0, 0),
#   'citations': 128,
#   'title': 'Depthwise Convolution is All You Need for Learning Multiple Visual Domains'},
#  {'date': datetime.datetime(2023, 2, 27, 0, 0),
#   'citations': 468,
#   'title': 'Language Is Not All You Need: Aligning Perception with Language Models'},
#  {'date': datetime.datetime(2021, 10, 1, 0, 0),
#   'citations': 36,
#   'title': 'One Timestep is All You Need: Training Spiking Neural Networks with Ultra Low Latency'},
#  {'date': datetime.datetime(2022, 7, 1, 0, 0),
#   'citations': 11,
#   'title': 'A BF16 FMA is All You Need for DNN Training'},
#  {'date': datetime.datetime(2022, 9, 14, 0, 0),
#   'citations': 11,
#   'title': 'Equity premium prediction: attention is all you need'},
#  {'date': datetime.datetime(2018, 10, 8, 0, 0),
#   'citations': 113,
#   'title': 'Three steps is all you need: fast, accurate, automatic scaling decisions for distributed streaming dataflows'},
#  {'date': datetime.datetime(2021, 9, 8, 0, 0),
#   'citations': 35,
#   'title': 'Mask is All You Need: Rethinking Mask R-CNN for Dense and Arbitrary-Shaped Scene Text Detection'},
#  {'date': datetime.datetime(2021, 6, 6, 0, 0),
#   'citations': 34,
#   'title': 'Bandwidth Extension is All You Need'},
#  {'date': datetime.datetime(2019, 4, 15, 0, 0),
#   'citations': 124,
#   'title': 'Focus Is All You Need: Loss Functions for Event-Based Vision'},
#  {'date': datetime.datetime(2021, 3, 9, 0, 0),
#   'citations': 27,
#   'title': 'GAN Vocoder: Multi-Resolution Discriminator Is All You Need'},
#  {'date': datetime.datetime(2021, 10, 17, 0, 0),
#   'citations': 26,
#   'title': 'Yes, "Attention Is All You Need", for Exemplar based Colorization'},
#  {'date': datetime.datetime(2023, 6, 20, 0, 0),
#   'citations': 318,
#   'title': 'Textbooks Are All You Need'},
#  {'date': datetime.datetime(2021, 12, 22, 0, 0),
#   'citations': 23,
#   'title': 'Cost Aggregation Is All You Need for Few-Shot Segmentation'},
#  {'date': datetime.datetime(2020, 11, 5, 0, 0),
#   'citations': 45,
#   'title': 'Language Model is all You Need: Natural Language Understanding as Question Answering'},
#  {'date': datetime.datetime(2020, 12, 25, 0, 0),
#   'citations': 35,
#   'title': 'A Simple Fine-tuning Is All You Need: Towards Robust Deep Learning Via Adversarial Fine-tuning'},
#  {'date': datetime.datetime(2022, 11, 28, 0, 0),
#   'citations': 280,
#   'title': 'Is Conditional Generative Modeling all you need for Decision-Making?'},
#  {'date': datetime.datetime(2021, 11, 8, 0, 0),
#   'citations': 19,
#   'title': 'Realizable Learning is All You Need'},
#  {'date': datetime.datetime(2021, 7, 11, 0, 0),
#   'citations': 18,
#   'title': 'Answer Complex Questions: Path Ranker Is All You Need'},
#  {'date': datetime.datetime(2021, 10, 29, 0, 0),
#   'citations': 18,
#   'title': 'Hyperparameter Tuning is All You Need for LISTA'},
#  {'date': datetime.datetime(2020, 8, 28, 0, 0),
#   'citations': 43,
#   'title': 'Against Membership Inference Attack: Pruning is All You Need'},
#  {'date': datetime.datetime(2021, 6, 6, 0, 0),
#   'citations': 1018,
#   'title': 'Tabular Data: Deep Learning is Not All You Need'},
#  {'date': datetime.datetime(2021, 6, 21, 0, 0),
#   'citations': 10,
#   'title': 'Clinically relevant pretraining is all you need'},
#  {'date': datetime.datetime(2021, 4, 10, 0, 0),
#   'citations': 9,
#   'title': 'Not All Attention Is All You Need'},
#  {'date': datetime.datetime(2022, 1, 24, 0, 0),
#   'citations': 373,
#   'title': 'Patches Are All You Need?'},
#  {'date': datetime.datetime(2020, 1, 3, 0, 0),
#   'citations': 24,
#   'title': 'Scalability and robustness of spectral embedding: landmark diffusion is all you need'},
#  {'date': datetime.datetime(2023, 3, 14, 0, 0),
#   'citations': 211,
#   'title': 'Attention is not all you need: the complicated case of ethically using large language models in healthcare and medicine'},
#  {'date': datetime.datetime(2023, 1, 11, 0, 0),
#   'citations': 222,
#   'title': 'ChatGPT is not all you need. A State of the Art Review of large Generative AI models'},
#  {'date': datetime.datetime(2020, 12, 1, 0, 0),
#   'citations': 17,
#   'title': 'Diffusion is All You Need for Learning on Surfaces'},
#  {'date': datetime.datetime(2023, 3, 21, 0, 0),
#   'citations': 139,
#   'title': 'A Complete Survey on Generative AI (AIGC): Is ChatGPT from GPT-4 to GPT-5 All You Need?'},
#  {'date': datetime.datetime(2019, 12, 5, 0, 0),
#   'citations': 47,
#   'title': '15 Keypoints Is All You Need'},
#  {'date': datetime.datetime(2019, 6, 16, 0, 0),
#   'citations': 47,
#   'title': 'One Epoch Is All You Need'},
#  {'date': datetime.datetime(2019, 10, 31, 0, 0),
#   'citations': 40,
#   'title': 'Attention Is All You Need for Chinese Word Segmentation'},
#  {'date': datetime.datetime(2023, 3, 13, 0, 0),
#   'citations': 60,
#   'title': 'Revisiting Class-Incremental Learning with Pre-Trained Models: Generalizability and Adaptivity are All You Need'},
#  {'date': datetime.datetime(2023, 3, 14, 0, 0),
#   'citations': 43,
#   'title': 'Parameter is Not All You Need: Starting from Non-Parametric Networks for 3D Point Cloud Analysis'},
#  {'date': datetime.datetime(2023, 12, 5, 0, 0),
#   'citations': 35,
#   'title': 'Is Ego Status All You Need for Open-Loop End-to-End Autonomous Driving?'},
#  {'date': datetime.datetime(2023, 10, 2, 0, 0),
#   'citations': 37,
#   'title': 'Linear attention is (maybe) all you need (to understand transformer optimization)'},
#  {'date': datetime.datetime(2023, 4, 13, 0, 0),
#   'citations': 39,
#   'title': 'Are Large Language Models All You Need for Task-Oriented Dialogue?'},
#  {'date': datetime.datetime(2019, 9, 7, 0, 0),
#   'citations': 28,
#   'title': 'LAMAL: LAnguage Modeling Is All You Need for Lifelong Language Learning'},
#  {'date': datetime.datetime(2023, 12, 26, 0, 0),
#   'citations': 49,
#   'title': 'Principled Instructions Are All You Need for Questioning LLaMA-1/2, GPT-3.5/4'},
#  {'date': datetime.datetime(2023, 10, 23, 0, 0),
#   'citations': 29,
#   'title': 'FIFO queues are all you need for cache eviction'},
#  {'date': datetime.datetime(2019, 4, 30, 0, 0),
#   'citations': 20,
#   'title': 'Segmentation is All You Need'},
#  {'date': datetime.datetime(2018, 6, 8, 0, 0),
#   'citations': 47,
#   'title': 'Cross-lingual Argumentation Mining: Machine Translation (and a bit of Projection) is All You Need!'},
#  {'date': datetime.datetime(2018, 5, 16, 0, 0),
#   'citations': 42,
#   'title': 'Trust is All You Need: An Empirical Exploration of Initial Coin Offerings (ICOs) and ICO Reputation Scores'},
#  {'date': datetime.datetime(2023, 8, 14, 0, 0),
#   'citations': 21,
#   'title': 'Global Features are All You Need for Image Retrieval and Reranking'},
#  {'date': datetime.datetime(2020, 6, 13, 0, 0),
#   'citations': 403,
#   'title': 'DeeperGCN: All You Need to Train Deeper GCNs'},
#  {'date': datetime.datetime(2023, 6, 12, 0, 0),
#   'citations': 22,
#   'title': 'AI Regulation Is (not) All You Need'},
#  {'date': datetime.datetime(2014, 6, 1, 0, 0),
#   'citations': 249,
#   'title': 'One lesson is all you need? Stability of instructional quality across lessons.'},
#  {'date': datetime.datetime(2023, 2, 22, 0, 0),
#   'citations': 15,
#   'title': 'Some Might Say All You Need Is Sum'},
#  {'date': datetime.datetime(2021, 3, 5, 0, 0),
#   'citations': 332,
#   'title': 'Attention is Not All You Need: Pure Attention Loses Rank Doubly Exponentially with Depth'},
#  {'date': datetime.datetime(2023, 2, 17, 0, 0),
#   'citations': 14,
#   'title': 'Conformers are All You Need for Visual Speech Recogntion'},
#  {'date': datetime.datetime(2020, 1, 20, 0, 0),
#   'citations': 300,
#   'title': 'All You Need Is Low (Rank): Defending Against Adversarial Attacks on Graphs'},
#  {'date': datetime.datetime(2021, 2, 16, 0, 0),
#   'citations': 185,
#   'title': 'All You Need is DAG'},
#  {'date': datetime.datetime(2018, 8, 29, 0, 0),
#   'citations': 7,
#   'title': 'Wasserstein is all you need'},
#  {'date': datetime.datetime(2017, 12, 27, 0, 0),
#   'citations': 17,
#   'title': 'CNN Is All You Need'},
#  {'date': datetime.datetime(2022, 10, 10, 0, 0),
#   'citations': 39,
#   'title': 'Certified Training: Small Boxes are All You Need'},
#  {'date': datetime.datetime(2022, 7, 1, 0, 0),
#   'citations': 50,
#   'title': 'A Review of the Etiology and Epidemiology of Bladder Cancer: All You Need To Know'},
#  {'date': datetime.datetime(2022, 3, 10, 0, 0),
#   'citations': 36,
#   'title': 'Back to the Feature: Classical 3D Features are (Almost) All You Need for 3D Anomaly Detection'},
#  {'date': datetime.datetime(2024, 4, 11, 0, 0),
#   'citations': 38,
#   'title': 'Rho-1: Not All Tokens Are What You Need'},
#  {'date': datetime.datetime(2022, 4, 1, 0, 0),
#   'citations': 39,
#   'title': 'New Perspectives in SWCNT Applications: Tuball SWCNTs.Part 1. Tuball by Itself – All You Need to Know about It.'},
#  {'date': datetime.datetime(2022, 6, 21, 0, 0),
#   'citations': 41,
#   'title': 'Questions Are All You Need to Train a Dense Passage Retriever'},
#  {'date': datetime.datetime(2015, 9, 23, 0, 0),
#   'citations': 64,
#   'title': 'Harm is all you need? Best interests and disputes about parental decision-making'},
#  {'date': datetime.datetime(2022, 6, 1, 0, 0),
#   'citations': 24,
#   'title': 'Computer-assisted Pronunciation Training - Speech synthesis is almost all you need'},
#  {'date': datetime.datetime(2022, 6, 19, 0, 0),
#   'citations': 23,
#   'title': 'All You Need Is Feedback: Communication With Block Attention Feedback Codes'},
#  {'date': datetime.datetime(2022, 9, 9, 0, 0),
#   'citations': 26,
#   'title': 'Fake News Spreaders Detection: Sometimes Attention Is Not All You Need'},
#  {'date': datetime.datetime(2022, 8, 22, 0, 0),
#   'citations': 17,
#   'title': 'Are disentangled representations all you need to build speaker anonymization systems?'},
#  {'date': datetime.datetime(2022, 6, 8, 0, 0),
#   'citations': 18,
#   'title': 'Words are all you need? Language as an approximation for human similarity judgments'},
#  {'date': datetime.datetime(2022, 11, 29, 0, 0),
#   'citations': 24,
#   'title': 'Out-Of-Distribution Detection Is Not All You Need'},
#  {'date': datetime.datetime(2022, 6, 23, 0, 0),
#   'citations': 16,
#   'title': 'Rethinking Surgical Instrument Segmentation: A Background Image Can Be All You Need'},
#  {'date': datetime.datetime(2021, 6, 3, 0, 0),
#   'citations': 48,
#   'title': 'Three Sentences Are All You Need: Local Path Enhanced Document Relation Extraction'},
#  {'date': datetime.datetime(2021, 4, 13, 0, 0),
#   'citations': 41,
#   'title': 'All you need are a few pixels: semantic segmentation with PixelPick'},
#  {'date': datetime.datetime(2020, 9, 29, 0, 0),
#   'citations': 507,
#   'title': 'All you need to know about model predictive control for buildings'},
#  {'date': datetime.datetime(2021, 8, 30, 0, 0),
#   'citations': 19,
#   'title': 'Rapid Speaker Adaptation for Conformer Transducer: Attention and Bias Are All You Need'},
#  {'date': datetime.datetime(2015, 4, 1, 0, 0),
#   'citations': 44,
#   'title': 'When virtual contact is all you need: Subtle reminders of Facebook preempt social‐contact restoration after exclusion'},
#  {'date': datetime.datetime(2020, 11, 18, 0, 0),
#   'citations': 270,
#   'title': 'Is Independent Learning All You Need in the StarCraft Multi-Agent Challenge?'},
#  {'date': datetime.datetime(2021, 11, 10, 0, 0),
#   'citations': 86,
#   'title': 'Gradients are Not All You Need'},
#  {'date': datetime.datetime(2021, 3, 25, 0, 0),
#   'citations': 58,
#   'title': 'More Photos are All You Need: Semi-Supervised Learning for Fine-Grained Sketch Based Image Retrieval'},
#  {'date': datetime.datetime(2021, 10, 8, 0, 0),
#   'citations': 56,
#   'title': 'All you need to know about sperm RNAs.'},
#  {'date': datetime.datetime(2021, 11, 3, 0, 0),
#   'citations': 39,
#   'title': 'Is Bang-Bang Control All You Need? Solving Continuous Control with Bernoulli Policies'},
#  {'date': datetime.datetime(2020, 5, 20, 0, 0),
#   'citations': 121,
#   'title': 'Is MAP Decoding All You Need? The Inadequacy of the Mode in Neural Machine Translation'},
#  {'date': datetime.datetime(2020, 10, 27, 0, 0),
#   'citations': 87,
#   'title': 'One Solution is Not All You Need: Few-Shot Extrapolation via Structured MaxEnt RL'},
#  {'date': datetime.datetime(2015, 10, 1, 0, 0),
#   'citations': 10,
#   'title': 'Knowledge Is All You Need'},
#  {'date': datetime.datetime(2012, 7, 1, 0, 0),
#   'citations': 71,
#   'title': 'A Little Flexibility is All You Need: On the Asymptotic Value of Flexible Capacity in Parallel Queuing Systems'},
#  {'date': datetime.datetime(2020, 4, 30, 0, 0),
#   'citations': 74,
#   'title': 'Sign Bits Are All You Need for Black-Box Attacks'},
#  {'date': datetime.datetime(2021, 7, 16, 0, 0),
#   'citations': 26,
#   'title': 'Is attention to bounding boxes all you need for pedestrian action prediction?'},
#  {'date': datetime.datetime(2021, 4, 14, 0, 0),
#   'citations': 19,
#   'title': 'Is Disentanglement all you need? Comparing Concept-based & Disentanglement Approaches'},
#  {'date': datetime.datetime(2021, 8, 30, 0, 0),
#   'citations': 18,
#   'title': 'Neural HMMS Are All You Need (For High-Quality Attention-Free TTS)'},
#  {'date': datetime.datetime(2021, 8, 14, 0, 0),
#   'citations': 20,
#   'title': 'All You Need to Know to Build a Product Knowledge Graph'},
#  {'date': datetime.datetime(2021, 7, 29, 0, 0),
#   'citations': 30,
#   'title': 'Protein structure prediction by AlphaFold2: are attention and symmetries all you need?'},
#  {'date': datetime.datetime(2021, 9, 17, 0, 0),
#   'citations': 18,
#   'title': 'Is Curiosity All You Need? On the Utility of Emergent Behaviours from Curious Exploration'},
#  {'date': datetime.datetime(2020, 11, 11, 0, 0),
#   'citations': 69,
#   'title': 'Breast cancer, screening and diagnostic tools: All you need to know.'},
#  {'date': datetime.datetime(2020, 12, 4, 0, 0),
#   'citations': 66,
#   'title': 'RPT: Relational Pre-trained Transformer Is Almost All You Need towards Democratizing Data Preparation'},
#  {'date': datetime.datetime(2020, 4, 1, 0, 0),
#   'citations': 62,
#   'title': 'Pre-training Is (Almost) All You Need: An Application to Commonsense Reasoning'},
#  {'date': datetime.datetime(2020, 11, 25, 0, 0),
#   'citations': 53,
#   'title': 'All You Need is a Good Functional Prior for Bayesian Deep Learning'},
#  {'date': datetime.datetime(2022, 2, 16, 0, 0),
#   'citations': 188,
#   'title': 'Not All Patches are What You Need: Expediting Vision Transformers via Token Reorganizations'},
#  {'date': datetime.datetime(2020, 11, 1, 0, 0),
#   'citations': 41,
#   'title': 'All You Need Is Light. Photorepair of UV-Induced Pyrimidine Dimers'},
#  {'date': datetime.datetime(2022, 5, 4, 0, 0),
#   'citations': 63,
#   'title': 'All You May Need for VQA are Image Captions'},
#  {'date': datetime.datetime(2019, 5, 27, 0, 0),
#   'citations': 137,
#   'title': 'Mixed Precision DNNs: All you need is a good parametrization'},
#  {'date': datetime.datetime(2019, 11, 21, 0, 0),
#   'citations': 121,
#   'title': 'All You Need Is Boundary: Toward Arbitrary-Shaped Text Spotting'},
#  {'date': datetime.datetime(2020, 11, 16, 0, 0),
#   'citations': 38,
#   'title': 'All You Need to Know About DPYD Genetic Testing for Patients Treated With Fluorouracil and Capecitabine: A Practitioner-Friendly Guide.'},
#  {'date': datetime.datetime(2019, 11, 24, 0, 0),
#   'citations': 88,
#   'title': 'Breaking the Cycle – Colleagues Are All You Need'},
#  {'date': datetime.datetime(2019, 4, 22, 0, 0),
#   'citations': 139,
#   'title': 'Finding All You Need: Web APIs Recommendation in Web of Things Through Keywords Search'},
#  {'date': datetime.datetime(2020, 11, 19, 0, 0),
#   'citations': 33,
#   'title': 'MixMix: All You Need for Data-Free Compression Are Feature and Data Mixing'},
#  {'date': datetime.datetime(2019, 1, 2, 0, 0),
#   'citations': 114,
#   'title': '‘All you need is brand love’: a critical review and comprehensive conceptual framework for brand love'},
#  {'date': datetime.datetime(2020, 9, 14, 0, 0),
#   'citations': 23,
#   'title': '"You are already all you need to be": A case illustration of compassion-focused therapy for shame and perfectionism.'},
#  {'date': datetime.datetime(2015, 11, 19, 0, 0),
#   'citations': 600,
#   'title': 'All you need is a good init'},
#  {'date': datetime.datetime(2020, 6, 14, 0, 0),
#   'citations': 19,
#   'title': 'Is Independence all you need? On the Generalization of Representations Learned from Correlated Data'},
#  {'date': datetime.datetime(2020, 8, 28, 0, 0),
#   'citations': 19,
#   'title': '3D Plant Phenotyping: All You Need is Labelled Point Cloud Data'},
#  {'date': datetime.datetime(2018, 1, 15, 0, 0),
#   'citations': 218,
#   'title': 'All You Need is "Love": Evading Hate Speech Detection'},
#  {'date': datetime.datetime(2018, 2, 1, 0, 0),
#   'citations': 270,
#   'title': 'All you need is shape: Predicting shear banding in sand with LS-DEM'},
#  {'date': datetime.datetime(2018, 11, 22, 0, 0),
#   'citations': 126,
#   'title': 'Bytes Are All You Need: End-to-end Multilingual Speech Recognition and Synthesis with Bytes'},
#  {'date': datetime.datetime(2019, 3, 13, 0, 0),
#   'citations': 78,
#   'title': 'All You Need Is a Few Shifts: Designing Efficient Convolutional Neural Networks for Image Classification'},
#  {'date': datetime.datetime(2018, 4, 24, 0, 0),
#   'citations': 78,
#   'title': 'Action research: all you need to know'},
#  {'date': datetime.datetime(2019, 5, 31, 0, 0),
#   'citations': 36,
#   'title': 'Attention Is (not) All You Need for Commonsense Reasoning'},
#  {'date': datetime.datetime(2013, 5, 1, 0, 0),
#   'citations': 11,
#   'title': 'Love Is All You Need'},
#  {'date': datetime.datetime(2017, 3, 6, 0, 0),
#   'citations': 175,
#   'title': 'All You Need is Beyond a Good Init: Exploring Better Solution for Training Extremely Deep Convolutional Neural Networks with Orthonormality and Modulation'},
#  {'date': datetime.datetime(1999, 2, 1, 0, 0),
#   'citations': 60,
#   'title': "Love is all you need? Focusing on adolescents' life concerns from an ecological point of view."},
#  {'date': datetime.datetime(2019, 6, 2, 0, 0),
#   'citations': 17,
#   'title': 'AYNEC: All You Need for Evaluating Completion Techniques in Knowledge Graphs'},
#  {'date': datetime.datetime(2017, 2, 1, 0, 0),
#   'citations': 106,
#   'title': 'Is Love All You Need? The Effects of Emotional Culture, Suppression, and Work–family Conflict on Firefighter Risk-Taking and Health'},
#  {'date': datetime.datetime(2007, 1, 1, 0, 0),
#   'citations': 30,
#   'title': 'The New Backlash: Popular Culture\'s "Marriage" with Feminism, or Love Is All You Need'},
#  {'date': datetime.datetime(2021, 4, 14, 0, 0),
#   'citations': 398,
#   'title': 'Lithium ion battery degradation: what you need to know.'},
#  {'date': datetime.datetime(2000, 10, 1, 0, 0),
#   'citations': 18,
#   'title': '"Love is all you need"? Student nurses\' interest in working with children.'},
#  {'date': datetime.datetime(1995, 2, 1, 0, 0),
#   'citations': 16,
#   'title': "‘Everyone's Agreed, the West is All You Need’"},
#  {'date': datetime.datetime(2008, 9, 1, 0, 0),
#   'citations': 10,
#   'title': 'Love is all you need'},
#  {'date': datetime.datetime(2017, 4, 10, 0, 0),
#   'citations': 14,
#   'title': 'Action Research: All You Need to Know'},
#  {'date': datetime.datetime(2017, 6, 18, 0, 0),
#   'citations': 15,
#   'title': 'Ground-Fault Protection: All You Need To Know'},
#  {'date': datetime.datetime(2015, 2, 1, 0, 0),
#   'citations': 145,
#   'title': 'All You Need Is Trust? An Examination of Inter‐organizational Supply Chain Projects'},
#  {'date': datetime.datetime(2018, 10, 3, 0, 0),
#   'citations': 1,
#   'title': 'All You Need Is LSD'},
#  {'date': datetime.datetime(2016, 6, 24, 0, 0),
#   'citations': 18,
#   'title': 'Restoring stem cells — all you need is NAD+'},
#  {'date': datetime.datetime(2001, 5, 1, 0, 0),
#   'citations': 4,
#   'title': 'RNA is all you need'},
#  {'date': datetime.datetime(2016, 7, 30, 0, 0),
#   'citations': 11,
#   'title': 'Leadership: All You Need To Know 2nd edition'},
#  {'date': datetime.datetime(2015, 2, 1, 0, 0),
#   'citations': 71,
#   'title': 'Demand Estimation and Ordering Under Censoring: Stock-Out Timing Is (Almost) All You Need'},
#  {'date': datetime.datetime(2020, 4, 30, 0, 0),
#   'citations': 217,
#   'title': 'Emergency surgery during the COVID-19 pandemic: what you need to know for practice.'},
#  {'date': datetime.datetime(2015, 10, 12, 0, 0),
#   'citations': 59,
#   'title': 'From System Services Freezing to System Server Shutdown in Android: All You Need Is a Loop in an App'},
#  {'date': datetime.datetime(2015, 9, 11, 0, 0),
#   'citations': 37,
#   'title': 'All you Need to Know About: The Cultivation Theory'},
#  {'date': datetime.datetime(2015, 1, 13, 0, 0),
#   'citations': 39,
#   'title': '‘All you need is love and £18,600’: Class and the new UK family migration rules'},
#  {'date': datetime.datetime(2020, 5, 4, 0, 0),
#   'citations': 138,
#   'title': 'The three numbers you need to know about healthcare: the 60-30-10 Challenge'},
#  {'date': datetime.datetime(2015, 12, 18, 0, 0),
#   'citations': 30,
#   'title': "Harm isn't all you need: parental discretion and medical decisions for a child"},
#  {'date': datetime.datetime(2000, 2, 1, 0, 0),
#   'citations': 0,
#   'title': 'Love Is All You Need'},
#  {'date': datetime.datetime(1998, 2, 1, 0, 0),
#   'citations': 0,
#   'title': 'Love Is All You Need'},
#  {'date': datetime.datetime(1994, 9, 24, 0, 0),
#   'citations': 0,
#   'title': 'Love is all you need.'},
#  {'date': datetime.datetime(2014, 7, 21, 0, 0),
#   'citations': 22,
#   'title': '“All You Need Is Love”: Considerations for a Social Justice Inquiry in Leisure Studies'},
#  {'date': datetime.datetime(2014, 6, 1, 0, 0),
#   'citations': 15,
#   'title': 'All You Need is Love?'},
#  {'date': datetime.datetime(2007, 9, 1, 0, 0),
#   'citations': 794,
#   'title': 'All You Need to Know about Action Research'},
#  {'date': datetime.datetime(2013, 2, 4, 0, 0),
#   'citations': 155,
#   'title': 'All you need is … resources: The effects of justice and support on burnout and turnover'},
#  {'date': datetime.datetime(2018, 2, 5, 0, 0),
#   'citations': 18,
#   'title': 'The Matrix Calculus You Need For Deep Learning'},
#  {'date': datetime.datetime(2018, 9, 6, 0, 0),
#   'citations': 71,
#   'title': 'What Blockchain Alternative Do You Need?'},
#  {'date': datetime.datetime(2013, 1, 21, 0, 0),
#   'citations': 9,
#   'title': 'All You Need to Know About...'},
#  {'date': datetime.datetime(2012, 3, 6, 0, 0),
#   'citations': 236,
#   'title': 'All you need is trust? A critical review of the trust and entrepreneurship literature'},
#  {'date': datetime.datetime(2012, 12, 1, 0, 0),
#   'citations': 230,
#   'title': 'All You Need is Love: Current Strategies of Mediating Intimate Relationships through Technology'},
#  {'date': datetime.datetime(2012, 1, 1, 0, 0),
#   'citations': 355,
#   'title': 'Targeting Sirtuin 1 to Improve Metabolism: All You Need Is NAD+?'},
#  {'date': datetime.datetime(2016, 4, 1, 0, 0),
#   'citations': 127,
#   'title': 'What you need is what you eat? Prey selection by the bat Myotis daubentonii'},
#  {'date': datetime.datetime(2016, 8, 10, 0, 0),
#   'citations': 95,
#   'title': 'All the AES You Need on Cortex-M3 and M4'},
#  {'date': datetime.datetime(2012, 8, 1, 0, 0),
#   'citations': 71,
#   'title': 'All you need to know about urethrovesical anastomotic urinary leakage following radical prostatectomy.'},
#  {'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'citations': 17,
#   'title': 'All you need to know about innovation in healthcare: The 10 best reads'},
#  {'date': datetime.datetime(2011, 11, 1, 0, 0),
#   'citations': 184,
#   'title': 'All you need is light'},
#  {'date': datetime.datetime(2011, 5, 1, 0, 0),
#   'citations': 99,
#   'title': 'All you need is love? Strengths mediate the negative associations between attachment orientations and life satisfaction'},
#  {'date': datetime.datetime(2011, 9, 19, 0, 0),
#   'citations': 35,
#   'title': 'Leadership: All You Need To Know'},
#  {'date': datetime.datetime(2007, 2, 1, 0, 0),
#   'citations': 430,
#   'title': 'Theory of quantitative reconstruction of vegetation II: all you need is LOVE'},
#  {'date': datetime.datetime(2010, 11, 1, 0, 0),
#   'citations': 40,
#   'title': 'Albuminuria: all you need to predict outcomes in chronic kidney disease?'},
#  {'date': datetime.datetime(2010, 7, 5, 0, 0),
#   'citations': 11,
#   'title': 'Domain-Specific Mashups: From All to All You Need'},
#  {'date': datetime.datetime(2009, 3, 18, 0, 0),
#   'citations': 22,
#   'title': "All you need is love: Is the sociometer especially sensitive to one's mating capacity?"},
#  {'date': datetime.datetime(2008, 1, 7, 0, 0),
#   'citations': 22,
#   'title': 'All You Need Is Compassion'},
#  {'date': datetime.datetime(2006, 12, 4, 0, 0),
#   'citations': 177,
#   'title': 'Transgenic Wnt/TCF pathway reporters: all you need is Lef?'},
#  {'date': datetime.datetime(2009, 6, 12, 0, 0),
#   'citations': 29,
#   'title': 'All you need is N: Baryon spectroscopy in two large N limits'},
#  {'date': datetime.datetime(2007, 12, 4, 0, 0),
#   'citations': 50,
#   'title': 'The ETF Book: All You Need to Know About Exchange-Traded Funds'},
#  {'date': datetime.datetime(2000, 6, 1, 0, 0),
#   'citations': 97,
#   'title': 'All You Want Is Money, All You Need Is Love: Sex and Romance in Modern India'},
#  {'date': datetime.datetime(2006, 3, 27, 0, 0),
#   'citations': 70,
#   'title': 'Linear Regions Are All You Need'},
#  {'date': datetime.datetime(2002, 6, 22, 0, 0),
#   'citations': 95,
#   'title': 'All you need is cognitive behaviour therapy?'},
#  {'date': datetime.datetime(1998, 5, 6, 0, 0),
#   'citations': 69,
#   'title': 'All you need is love : the Peace Corps and the spirit of the 1960s'},
#  {'date': datetime.datetime(1993, 9, 30, 0, 0),
#   'citations': 70,
#   'title': 'Computing Treewidth and Minimum Fill-In: All You Need are the Minimal Separators'},
#  {'date': datetime.datetime(2005, 9, 27, 0, 0),
#   'citations': 34,
#   'title': 'Lend Me Your Ears: All You Need to Know about Making Speeches and Presentations'},
#  {'date': datetime.datetime(1996, 11, 13, 0, 0),
#   'citations': 32,
#   'title': 'Wound care. All you need to know about ... maggots.'},
#  {'date': datetime.datetime(1999, 2, 1, 0, 0),
#   'citations': 27,
#   'title': 'All You Need is Love: The Peace Corps and the Spirit of the 1960s.'},
#  {'date': datetime.datetime(1976, 11, 1, 0, 0),
#   'citations': 12,
#   'title': 'All You Need Is Love: The Story of Popular Music'},
#  {'date': datetime.datetime(2005, 10, 18, 0, 0),
#   'citations': 18,
#   'title': 'All You Need Is LAV: Madonna and Postmodern Kabbalah'},
#  {'date': datetime.datetime(2008, 10, 1, 0, 0),
#   'citations': 7,
#   'title': 'All you need to know.'},
#  {'date': datetime.datetime(1999, 9, 1, 0, 0),
#   'citations': 11,
#   'title': 'Soccer in Japan: Is wa all you need?'},
#  {'date': datetime.datetime(2006, 5, 23, 0, 0),
#   'citations': 12,
#   'title': 'All you need is log'},
#  {'date': datetime.datetime(1998, 7, 31, 0, 0),
#   'citations': 11,
#   'title': 'All You Need Is RNA'},
#  {'date': datetime.datetime(1992, 4, 1, 0, 0),
#   'citations': 62,
#   'title': 'All You Really Need to Know to Interpret Arterial Blood Gases'},
#  {'date': datetime.datetime(2010, 4, 1, 0, 0),
#   'citations': 852,
#   'title': 'How Many Studies Do You Need?'},
#  {'date': datetime.datetime(2020, 3, 16, 0, 0),
#   'citations': 49,
#   'title': 'All eyes on Coronavirus—What do we need to know as ophthalmologists'},
#  {'date': datetime.datetime(2012, 9, 12, 0, 0),
#   'citations': 68,
#   'title': "You can't always get what you want, but if you try sometimes (with two tests—TST and IGRA—for tuberculosis) you get what you need"},
#  {'date': datetime.datetime(2012, 1, 1, 0, 0),
#   'citations': 51,
#   'title': 'Do You Need a New Product-Development Strategy?'},
#  {'date': datetime.datetime(2011, 6, 8, 0, 0),
#   'citations': 64,
#   'title': 'Encryption: High-impact Strategies - What You Need to Know Definitions, Adoptions, Impact, Benefits, Maturity, Vendors'},
#  {'date': datetime.datetime(2011, 12, 20, 0, 0),
#   'citations': 34,
#   'title': 'When do you need a validated assay?'},
#  {'date': datetime.datetime(2010, 7, 16, 0, 0),
#   'citations': 132,
#   'title': 'The Truth about Leadership: The No-Fads, Heart-Of-The-Matter Facts You Need to Know'},
#  {'date': datetime.datetime(2008, 9, 1, 0, 0),
#   'citations': 32,
#   'title': 'Food Allergies--What You Need to Know'},
#  {'date': datetime.datetime(2005, 3, 8, 0, 0),
#   'citations': 57,
#   'title': 'The One Thing You Need to Know: ... About Great Managing, Great Leading, and Sustained Individual Success'},
#  {'date': datetime.datetime(2002, 9, 1, 0, 0),
#   'citations': 242,
#   'title': 'Three questions you need to ask about your brand.'},
#  {'date': datetime.datetime(2006, 3, 14, 0, 0),
#   'citations': 52,
#   'title': 'IEC 61850: What You Need to Know About Functionality and Practical Implementation'},
#  {'date': datetime.datetime(2000, 9, 1, 0, 0),
#   'citations': 107,
#   'title': 'Getting the attention you need.'},
#  {'date': datetime.datetime(2001, 5, 15, 0, 0),
#   'citations': 115,
#   'title': 'Cyclin specificity: how many wheels do you need on a unicycle?'},
#  {'date': datetime.datetime(2002, 7, 15, 0, 0),
#   'citations': 114,
#   'title': 'Corporate Longitude: What You Need to Know to Navigate the Knowledge Economy'},
#  {'date': datetime.datetime(1999, 2, 23, 0, 0),
#   'citations': 65,
#   'title': 'Breaking Through Culture Shock: What You Need to Succeed in International Business'},
#  {'date': datetime.datetime(2005, 10, 1, 0, 0),
#   'citations': 887,
#   'title': 'The perils of DNA barcoding and the need for integrative taxonomy.'},
#  {'date': datetime.datetime(2014, 7, 13, 0, 0),
#   'citations': 73,
#   'title': 'Once you SCOOP, no need to fork'},
#  {'date': datetime.datetime(2014, 4, 11, 0, 0),
#   'citations': 72,
#   'title': 'Foundations for Designing User-Centered Systems: What System Designers Need to Know about People'},
#  {'date': datetime.datetime(2018, 9, 17, 0, 0),
#   'citations': 3725,
#   'title': 'Leading change'},
#  {'date': datetime.datetime(2017, 4, 18, 0, 0),
#   'citations': 2725,
#   'title': 'Hands-On Machine Learning with Scikit-Learn and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems'},
#  {'date': datetime.datetime(2010, 7, 13, 0, 0),
#   'citations': 2791,
#   'title': 'Business Model Generation: A handbook for visionaries, game changers and challengers'},
#  {'date': datetime.datetime(2000, 6, 1, 0, 0),
#   'citations': 521,
#   'title': 'Effects of Stem and Likert Response Option Reversals on Survey Internal Consistency: If You Feel the Need, There is a Better Alternative to Using those Negatively Worded Stems'},
#  {'date': datetime.datetime(2014, 7, 1, 0, 0),
#   'citations': 42,
#   'title': 'Atopic dermatitis – all you can do from the outside'},
#  {'date': datetime.datetime(2004, 9, 20, 0, 0),
#   'citations': 1970,
#   'title': 'Pathology and genetics of tumours of the lung , pleura, thymus and heart'},
#  {'date': datetime.datetime(2012, 4, 1, 0, 0),
#   'citations': 78,
#   'title': 'You may need the vagus nerve to understand pathophysiology and to treat diseases.'},
#  {'date': datetime.datetime(2012, 4, 1, 0, 0),
#   'citations': 78,
#   'title': 'You may need the vagus nerve to understand pathophysiology and to treat diseases.'},
#  {'date': datetime.datetime(2000, 10, 11, 0, 0),
#   'citations': 1510,
#   'title': 'Understanding the Linux Kernel'},
#  {'date': datetime.datetime(2000, 9, 8, 0, 0),
#   'citations': 13943,
#   'title': 'Data Mining: Concepts and Techniques'},
#  {'date': datetime.datetime(2019, 7, 31, 0, 0),
#   'citations': 11294,
#   'title': 'Variable Selection'},
#  {'date': datetime.datetime(2016, 3, 28, 0, 0),
#   'citations': 1281,
#   'title': 'Platform Revolution: How Networked Markets Are Transforming the Economy--and How to Make Them Work for You'},
#  {'date': datetime.datetime(2003, 4, 21, 0, 0),
#   'citations': 2231,
#   'title': 'MDA explained - the Model Driven Architecture: practice and promise'},
#  {'date': datetime.datetime(2014, 12, 27, 0, 0),
#   'citations': 756,
#   'title': 'Mastering Bitcoin: Unlocking Digital Crypto-Currencies'},
#  {'date': datetime.datetime(1998, 9, 1, 0, 0),
#   'citations': 1888,
#   'title': 'Building the data warehouse'},
#  {'date': datetime.datetime(2019, 4, 26, 0, 0),
#   'citations': 1102,
#   'title': 'Maslow’s Hierarchy of Needs'},
#  {'date': datetime.datetime(2010, 10, 29, 0, 0),
#   'citations': 159,
#   'title': 'Heroes: What They Do and Why We Need Them'},
#  {'date': datetime.datetime(1974, 9, 1, 0, 0),
#   'citations': 2310,
#   'title': 'The Nature of Managerial Work'},
#  {'date': datetime.datetime(2023, 6, 23, 0, 0),
#   'citations': 360,
#   'title': 'YOLO-v1 to YOLO-v8, the Rise of YOLO and Its Complementary Nature toward Digital Manufacturing and Industrial Defect Detection'},
#  {'date': datetime.datetime(1998, 9, 16, 0, 0),
#   'citations': 1833,
#   'title': 'Requirements Engineering: Processes and Techniques'},
#  {'date': datetime.datetime(1994, 9, 1, 0, 0),
#   'citations': 1936,
#   'title': 'A Step-by-Step Approach to Using the SAS System for Factor Analysis and Structural Equation Modeling'},
#  {'date': datetime.datetime(2009, 10, 1, 0, 0),
#   'citations': 62,
#   'title': 'We need publishing standards for datasets and data tables'},
#  {'date': datetime.datetime(2018, 4, 25, 0, 0),
#   'citations': 554,
#   'title': 'Depression and anxiety in patients with cancer'},
#  {'date': datetime.datetime(2005, 2, 3, 0, 0),
#   'citations': 992,
#   'title': 'The Art of Computer Virus Research and Defense'},
#  {'date': datetime.datetime(2002, 1, 24, 0, 0),
#   'citations': 1287,
#   'title': 'Reputation helps solve the ‘tragedy of the commons’'},
#  {'date': datetime.datetime(2012, 7, 30, 0, 0),
#   'citations': 704,
#   'title': "Rang and Dale's pharmacology"},
#  {'date': datetime.datetime(2019, 7, 11, 0, 0),
#   'citations': 427,
#   'title': 'Setting the scene.'},
#  {'date': datetime.datetime(1995, 10, 1, 0, 0),
#   'citations': 1301,
#   'title': 'Book review: Essentials of Fuzzy Modeling and Control by Ronald R. Yager and Dimitar P. Filev (John Wiley, 1994)'},
#  {'date': datetime.datetime(1977, 6, 1, 0, 0),
#   'citations': 2179,
#   'title': 'HABITAT, THE TEMPLET FOR ECOLOGICAL STRATEGIES?'},
#  {'date': datetime.datetime(2019, 5, 3, 0, 0),
#   'citations': 371,
#   'title': 'Deconstructing Lottery Tickets: Zeros, Signs, and the Supermask'},
#  {'date': datetime.datetime(2010, 2, 1, 0, 0),
#   'citations': 64,
#   'title': 'Co-morbidity: we need a guideline for each patient not a guideline for each disease.'},
#  {'date': datetime.datetime(1997, 3, 7, 0, 0),
#   'citations': 112,
#   'title': 'I Love a Cop: What Police Families Need to Know'},
#  {'date': datetime.datetime(1981, 8, 1, 0, 0),
#   'citations': 1611,
#   'title': 'Problem-Based Learning: An Approach to Medical Education'},
#  {'date': datetime.datetime(2019, 6, 12, 0, 0),
#   'citations': 295,
#   'title': 'The strong perfect graph theorem'},
#  {'date': datetime.datetime(2006, 7, 1, 0, 0),
#   'citations': 30,
#   'title': 'What Leaders Need to Know and Do: A Leadership Competencies Scorecard'},
#  {'date': datetime.datetime(2004, 6, 7, 0, 0),
#   'citations': 250,
#   'title': "Haploinsufficiency for tumour suppressor genes: when you don't need to go all the way."},
#  {'date': datetime.datetime(2003, 9, 1, 0, 0),
#   'citations': 238,
#   'title': 'Teaching Democracy: What Schools Need to Do'},
#  {'date': datetime.datetime(1993, 12, 1, 0, 0),
#   'citations': 1102,
#   'title': 'Energy and Protein Requirements of Ruminants'},
#  {'date': datetime.datetime(2011, 9, 12, 0, 0),
#   'citations': 24,
#   'title': 'Need for Cognition Scale'},
#  {'date': datetime.datetime(2002, 4, 1, 0, 0),
#   'citations': 794,
#   'title': '802.11 Wireless Networks: The Definitive Guide'},
#  {'date': datetime.datetime(2006, 7, 14, 0, 0),
#   'citations': 125,
#   'title': 'Why Do You “Need to Know”? Context‐based education'},
#  {'date': datetime.datetime(2010, 4, 7, 0, 0),
#   'citations': 726,
#   'title': 'Adams and Victor’s Principles of Neurology'},
#  {'date': datetime.datetime(2011, 7, 23, 0, 0),
#   'citations': 622,
#   'title': 'Distributed Coordination of Multi-agent Networks'},
#  {'date': datetime.datetime(1964, 12, 31, 0, 0),
#   'citations': 1607,
#   'title': 'Distribution of zeros of entire functions'},
#  {'date': datetime.datetime(2001, 4, 10, 0, 0),
#   'citations': 1058,
#   'title': 'The war for talent'},
#  {'date': datetime.datetime(2007, 9, 10, 0, 0),
#   'citations': 687,
#   'title': 'Memory Systems: Cache, DRAM, Disk'},
#  {'date': datetime.datetime(2015, 2, 1, 0, 0),
#   'citations': 417,
#   'title': 'Grade Level: Tracking Online Education in the United States.'},
#  {'date': datetime.datetime(2009, 3, 1, 0, 0),
#   'citations': 549,
#   'title': 'Case study research in applied linguistics'},
#  {'date': datetime.datetime(2012, 8, 30, 0, 0),
#   'citations': 462,
#   'title': 'Raspberry Pi User Guide'},
#  {'date': datetime.datetime(1994, 12, 1, 0, 0),
#   'citations': 29,
#   'title': 'Why Do We Need This Class? Multicultural Education for Teachers'},
#  {'date': datetime.datetime(2014, 11, 9, 0, 0),
#   'citations': 376,
#   'title': 'The Business Model Navigator: 55 Models That Will Revolutionise Your Business'},
#  {'date': datetime.datetime(1996, 4, 1, 0, 0),
#   'citations': 58,
#   'title': 'On the need for evidence-based general and family practice'},
#  {'date': datetime.datetime(2005, 6, 30, 0, 0),
#   'citations': 680,
#   'title': 'Statistics Without Maths for Psychology: Using Spss for Windows'},
#  {'date': datetime.datetime(2018, 1, 1, 0, 0),
#   'citations': 293,
#   'title': 'The Markov blankets of life: autonomy, active inference and the free energy principle'},
#  {'date': datetime.datetime(1993, 6, 11, 0, 0),
#   'citations': 37,
#   'title': "President's Lecture: The Need for Scientific Communication with the Public."},
#  {'date': datetime.datetime(2010, 10, 25, 0, 0),
#   'citations': 457,
#   'title': 'Love in the Time of AIDS: Inequality, Gender, and Rights in South Africa'},
#  {'date': datetime.datetime(2017, 10, 15, 0, 0),
#   'citations': 303,
#   'title': 'Dealing with the positive publication bias: Why you should really publish your negative results'},
#  {'date': datetime.datetime(2015, 9, 11, 0, 0),
#   'citations': 271,
#   'title': 'Teaching in a Digital Age'},
#  {'date': datetime.datetime(1977, 8, 1, 0, 0),
#   'citations': 994,
#   'title': 'The Rat: A Study in Behavior.'},
#  {'date': datetime.datetime(2002, 2, 21, 0, 0),
#   'citations': 734,
#   'title': 'A Practical Guide to Feature-Driven Development'},
#  {'date': datetime.datetime(2006, 12, 4, 0, 0),
#   'citations': 625,
#   'title': 'Friends, Friendsters, and Top 8: Writing community into being on social network sites'},
#  {'date': datetime.datetime(2019, 4, 17, 0, 0),
#   'citations': 137,
#   'title': "Chestnut's Obstetric Anesthesia: Principles and Practice"},
#  {'date': datetime.datetime(2005, 4, 1, 0, 0),
#   'citations': 648,
#   'title': 'Web Services Platform Architecture: SOAP, WSDL, WS-Policy, WS-Addressing, WS-BPEL, WS-Reliable Messaging, and More'},
#  {'date': datetime.datetime(2015, 9, 18, 0, 0),
#   'citations': 211,
#   'title': 'On "The Coddling of the American Mind"'},
#  {'date': datetime.datetime(2009, 4, 1, 0, 0),
#   'citations': 509,
#   'title': 'Instructional Rounds in Education: A Network Approach to Improving Teaching and Learning'},
#  {'date': datetime.datetime(2000, 7, 1, 0, 0),
#   'citations': 551,
#   'title': 'Teacher Evaluation to Enhance Professional Practice'},
#  {'date': datetime.datetime(1997, 1, 10, 0, 0),
#   'citations': 651,
#   'title': 'Mastering Regular Expressions'},
#  {'date': datetime.datetime(2020, 11, 26, 0, 0),
#   'citations': 100,
#   'title': 'Handbook of Energy Audits'},
#  {'date': datetime.datetime(2013, 5, 14, 0, 0),
#   'citations': 293,
#   'title': 'The End of Competitive Advantage: How to Keep Your Strategy Moving as Fast as Your Business'},
#  {'date': datetime.datetime(2003, 10, 1, 0, 0),
#   'citations': 663,
# ...
#   'citations': 54,
#   'title': 'Pathology of the Esophagus'},
#  {'date': datetime.datetime(1976, 8, 1, 0, 0),
#   'citations': 63,
#   'title': 'Is psychology a profession?'},
#  {'date': datetime.datetime(2003, 6, 1, 0, 0),
#   'citations': 53,
#   'title': 'The Psychology of Problem Solving: The Fundamental Computational Biases of Human Cognition: Heuristics That (Sometimes) Impair Decision Making and Problem Solving'},
#  {'date': datetime.datetime(1990, 1, 3, 0, 0),
#   'citations': 47,
#   'title': 'Digital systems design with programmable logic'},
#  {'date': datetime.datetime(1969, 2, 1, 0, 0),
#   'citations': 57,
#   'title': 'The Riddle of Gravitation'},
#  {'date': datetime.datetime(2005, 10, 1, 0, 0),
#   'citations': 59,
#   'title': 'Privacy Preserving Data Mining (Advances in Information Security)'},
#  {'date': datetime.datetime(1990, 4, 1, 0, 0),
#   'citations': 64,
#   'title': 'Where does reuse start?'},
#  {'date': datetime.datetime(1989, 2, 1, 0, 0),
#   'citations': 65,
#   'title': 'Theory of finite automata with an introduction to formal languages'},
#  {'date': datetime.datetime(1991, 12, 2, 0, 0),
#   'citations': 41,
#   'title': 'Phonetic Analysis of Normal and Abnormal Speech'},
#  {'date': datetime.datetime(1973, 9, 1, 0, 0),
#   'citations': 60,
#   'title': 'Life and death and medicine.'},
#  {'date': datetime.datetime(1987, 11, 1, 0, 0),
#   'citations': 46,
#   'title': 'The Panic of 1857 and the Coming of the Civil War'},
#  {'date': datetime.datetime(1984, 11, 1, 0, 0),
#   'citations': 52,
#   'title': 'For goodness sake'},
#  {'date': datetime.datetime(1989, 4, 1, 0, 0),
#   'citations': 67,
#   'title': 'Lithium: Inorganic Pharmacology and Psychiatric Use'},
#  {'date': datetime.datetime(1936, 2, 1, 0, 0),
#   'citations': 75,
#   'title': 'Hospital Organization and Management'},
#  {'date': datetime.datetime(1981, 2, 20, 0, 0),
#   'citations': 45,
#   'title': 'Animals, Aging, and the Aged'},
#  {'date': datetime.datetime(1988, 3, 1, 0, 0),
#   'citations': 39,
#   'title': 'Prostaglandins and Related Substances. A Practical Approach'},
#  {'date': datetime.datetime(2003, 12, 1, 0, 0),
#   'citations': 47,
#   'title': 'Osteoporosis: Pathophysiology and Clinical Management.'},
#  {'date': datetime.datetime(1991, 9, 1, 0, 0),
#   'citations': 61,
#   'title': 'How the Nintendo generation learns'},
#  {'date': datetime.datetime(1983, 10, 12, 0, 0),
#   'citations': 64,
#   'title': 'Issues For Community College Leaders In A New Era'},
#  {'date': datetime.datetime(1956, 6, 1, 0, 0),
#   'citations': 61,
#   'title': 'A Pictorial History of Medicine'},
#  {'date': datetime.datetime(1995, 2, 1, 0, 0),
#   'citations': 31,
#   'title': 'The ODBC Solution: Open Database Connectivity in Distributed Environments'},
#  {'date': datetime.datetime(1988, 2, 3, 0, 0),
#   'citations': 36,
#   'title': 'The Philadelphia Story'},
#  {'date': datetime.datetime(1994, 9, 1, 0, 0),
#   'citations': 26,
#   'title': "All Change!: The Project Leader's Secret Handbook"},
#  {'date': datetime.datetime(1998, 12, 1, 0, 0),
#   'citations': 40,
#   'title': 'New Workspace New Culture - Office Design as a Catalyst for Change'},
#  {'date': datetime.datetime(1994, 9, 1, 0, 0),
#   'citations': 30,
#   'title': 'We Are All Self-Employed: The New Social Contract for Working in a Changed World'},
#  {'date': datetime.datetime(1958, 8, 1, 0, 0),
#   'citations': 42,
#   'title': 'The human ear canal.'},
#  {'date': datetime.datetime(1996, 11, 1, 0, 0),
#   'citations': 36,
#   'title': 'High Standards in a Tracked System of Schooling: For Which Students and With What Educational Supports?'},
#  {'date': datetime.datetime(1990, 8, 1, 0, 0),
#   'citations': 45,
#   'title': 'Statistical Process Control in Automated Manufacturing'},
#  {'date': datetime.datetime(1989, 11, 1, 0, 0),
#   'citations': 42,
#   'title': 'Writing Realism: Howells, James, and Norris in the Mass Market'},
#  {'date': datetime.datetime(2005, 8, 24, 0, 0),
#   'citations': 18,
#   'title': 'All About Derivatives'},
#  {'date': datetime.datetime(2000, 11, 1, 0, 0),
#   'citations': 26,
#   'title': 'Greatest myth of all'},
#  {'date': datetime.datetime(1978, 10, 1, 0, 0),
#   'citations': 40,
#   'title': 'The Politics of International Economic Relations'},
#  {'date': datetime.datetime(1932, 6, 1, 0, 0),
#   'citations': 41,
#   'title': 'Man and Medicine'},
#  {'date': datetime.datetime(1989, 8, 1, 0, 0),
#   'citations': 19,
#   'title': 'All our yesterdays.'},
#  {'date': datetime.datetime(2010, 5, 3, 0, 0),
#   'citations': 5418,
#   'title': 'The unified modeling language reference manual'},
#  {'date': datetime.datetime(2017, 12, 1, 0, 0),
#   'citations': 912,
#   'title': 'Grit: The Power of Passion and Perseverance'},
#  {'date': datetime.datetime(2018, 9, 3, 0, 0),
#   'citations': 840,
#   'title': 'Introduction to Quantum Mechanics'},
#  {'date': datetime.datetime(2015, 5, 8, 0, 0),
#   'citations': 654,
#   'title': 'How many biological replicates are needed in an RNA-seq experiment and which differential expression tool should you use?'},
#  {'date': datetime.datetime(2016, 8, 10, 0, 0),
#   'citations': 602,
#   'title': 'Everything You Wanted to Know About Smart Cities'},
#  {'date': datetime.datetime(2007, 4, 1, 0, 0),
#   'citations': 4545,
#   'title': 'Lean thinking, banish waste and create wealth in your corporation'},
#  {'date': datetime.datetime(1998, 11, 1, 0, 0),
#   'citations': 5766,
#   'title': 'Survey research methods'},
#  {'date': datetime.datetime(2002, 11, 1, 0, 0),
#   'citations': 2027,
#   'title': 'Test Driven Development: By Example'},
#  {'date': datetime.datetime(1976, 11, 1, 0, 0),
#   'citations': 3298,
#   'title': 'Primary, Secondary, and Meta-Analysis of Research1'},
#  {'date': datetime.datetime(2001, 9, 15, 0, 0),
#   'citations': 2146,
#   'title': 'The challenge of complexity in health care'},
#  {'date': datetime.datetime(1997, 3, 1, 0, 0),
#   'citations': 2008,
#   'title': 'Systematic Reviews: Synthesis of Best Evidence for Clinical Decisions'},
#  {'date': datetime.datetime(2003, 2, 1, 0, 0),
#   'citations': 1248,
#   'title': 'Logistic Regression: A Self-Learning Text'},
#  {'date': datetime.datetime(2019, 10, 1, 0, 0),
#   'citations': 356,
#   'title': 'Burned out'},
#  {'date': datetime.datetime(2009, 12, 8, 0, 0),
#   'citations': 2632,
#   'title': 'Doing Qualitative Research'},
#  {'date': datetime.datetime(2002, 5, 31, 0, 0),
#   'citations': 1094,
#   'title': 'System Design with SystemC'},
#  {'date': datetime.datetime(1993, 3, 1, 0, 0),
#   'citations': 1246,
#   'title': 'Syndromes of the Head and Neck'},
#  {'date': datetime.datetime(2013, 2, 12, 0, 0),
#   'citations': 538,
#   'title': 'Embodied Cognition is Not What you Think it is'},
#  {'date': datetime.datetime(2013, 1, 15, 0, 0),
#   'citations': 389,
#   'title': 'The Definitive ANTLR 4 Reference'},
#  {'date': datetime.datetime(2002, 5, 14, 0, 0),
#   'citations': 968,
#   'title': 'Executable UML - A Foundation for Model-Driven Architecture'},
#  {'date': datetime.datetime(2011, 3, 1, 0, 0),
#   'citations': 559,
#   'title': 'The Gay Science'},
#  {'date': datetime.datetime(2002, 9, 20, 0, 0),
#   'citations': 831,
#   'title': 'Honeypots: Tracking Hackers'},
#  {'date': datetime.datetime(2003, 5, 7, 0, 0),
#   'citations': 808,
#   'title': 'Assessment as Learning: Using Classroom Assessment to Maximize Student Learning'},
#  {'date': datetime.datetime(2013, 5, 1, 0, 0),
#   'citations': 264,
#   'title': 'Doing research in business & management: an essential guide to planning your project'},
#  {'date': datetime.datetime(1986, 6, 1, 0, 0),
#   'citations': 906,
#   'title': 'On Postmodernism and Articulation'},
#  {'date': datetime.datetime(2000, 4, 1, 0, 0),
#   'citations': 616,
#   'title': 'Community Building on the Web: Secret Strategies for Successful Online Communities'},
#  {'date': datetime.datetime(2015, 5, 20, 0, 0),
#   'citations': 181,
#   'title': 'Understanding Your Users: A Practical Guide to User Research Methods'},
#  {'date': datetime.datetime(2019, 4, 3, 0, 0),
#   'citations': 107,
#   'title': 'The case against education: why the education system is a waste of time and money'},
#  {'date': datetime.datetime(2012, 2, 10, 0, 0),
#   'citations': 188,
#   'title': 'The Cucumber Book: Behaviour-Driven Development for Testers and Developers'},
#  {'date': datetime.datetime(1999, 12, 7, 0, 0),
#   'citations': 615,
#   'title': 'The Knowledge Management Toolkit: Practical Techniques for Building a Knowledge Management System with Cdrom'},
#  {'date': datetime.datetime(2008, 8, 11, 0, 0),
#   'citations': 457,
#   'title': 'Cloud Computing: Web-Based Applications That Change the Way You Work and Collaborate Online'},
#  {'date': datetime.datetime(1994, 9, 1, 0, 0),
#   'citations': 607,
#   'title': "The Mind Map Book: How to Use Radiant Thinking to Maximize Your Brain's Untapped Potential"},
#  {'date': datetime.datetime(1995, 8, 3, 0, 0),
#   'citations': 622,
#   'title': 'How to Conduct Self-Administered and Mail Surveys'},
#  {'date': datetime.datetime(2000, 10, 26, 0, 0),
#   'citations': 456,
#   'title': 'Extreme Programming Installed'},
#  {'date': datetime.datetime(2008, 5, 6, 0, 0),
#   'citations': 447,
#   'title': 'Diophantine Equations'},
#  {'date': datetime.datetime(2016, 5, 16, 0, 0),
#   'citations': 101,
#   'title': 'Rumination-Focused Cognitive Behavioral Therapy'},
#  {'date': datetime.datetime(2005, 4, 5, 0, 0),
#   'citations': 479,
#   'title': 'User Interface Design and Evaluation'},
#  {'date': datetime.datetime(2002, 7, 8, 0, 0),
#   'citations': 524,
#   'title': 'Pair Programming Illuminated'},
#  {'date': datetime.datetime(2000, 9, 1, 0, 0),
#   'citations': 522,
#   'title': 'Virtual Teams: People Working Across Boundaries with Technology, Second Edition'},
#  {'date': datetime.datetime(2009, 8, 27, 0, 0),
#   'citations': 302,
#   'title': 'Pro Git'},
#  {'date': datetime.datetime(2011, 3, 8, 0, 0),
#   'citations': 250,
#   'title': 'CMMI for Development: Guidelines for Process Integration and Product Improvement'},
#  {'date': datetime.datetime(2008, 6, 30, 0, 0),
#   'citations': 345,
#   'title': 'Fuzzing for Software Security Testing and Quality Assurance'},
#  {'date': datetime.datetime(2008, 11, 24, 0, 0),
#   'citations': 362,
#   'title': 'Professional Android Application Development'},
#  {'date': datetime.datetime(2003, 6, 1, 0, 0),
#   'citations': 273,
#   'title': 'Chris Crawford on Game Design'},
#  {'date': datetime.datetime(2012, 12, 26, 0, 0),
#   'citations': 164,
#   'title': 'Kinect for Windows SDK Programming Guide'},
#  {'date': datetime.datetime(2012, 10, 17, 0, 0),
#   'citations': 220,
#   'title': 'A Preclinical Evaluation of Minnelide as a Therapeutic Agent Against Pancreatic Cancer'},
#  {'date': datetime.datetime(1989, 4, 30, 0, 0),
#   'citations': 587,
#   'title': 'Handbook of Pressure Sensitive Adhesive Technology'},
#  {'date': datetime.datetime(2012, 3, 19, 0, 0),
#   'citations': 192,
#   'title': 'Taming The Big Data Tidal Wave: Finding Opportunities in Huge Data Streams with Advanced Analytics'},
#  {'date': datetime.datetime(1996, 12, 1, 0, 0),
#   'citations': 476,
#   'title': "Information Exchange and Use in Group Decision Making: You Can Lead a Group to Information, but You Can't Make It Think"},
#  {'date': datetime.datetime(2003, 3, 8, 0, 0),
#   'citations': 412,
#   'title': 'The CG Tutorial: The Definitive Guide to Programmable Real-Time Graphics'},
#  {'date': datetime.datetime(2007, 9, 22, 0, 0),
#   'citations': 303,
#   'title': 'No Caption Needed: Iconic Photographs, Public Culture, and Liberal Democracy'},
#  {'date': datetime.datetime(1997, 9, 1, 0, 0),
#   'citations': 426,
#   'title': 'Do you see what I see? The future of virtual shopping'},
#  {'date': datetime.datetime(1993, 12, 31, 0, 0),
#   'citations': 268,
#   'title': 'The LaTeX companion'},
#  {'date': datetime.datetime(2002, 8, 1, 0, 0),
#   'citations': 373,
#   'title': 'The Design of Sites: Patterns, Principles, and Processes for Crafting a Customer-Centered Web Experience'},
#  {'date': datetime.datetime(2010, 10, 5, 0, 0),
#   'citations': 239,
#   'title': 'Where Good Ideas Come From'},
#  {'date': datetime.datetime(1999, 3, 1, 0, 0),
#   'citations': 391,
#   'title': 'Doing a literature review'},
#  {'date': datetime.datetime(2010, 1, 6, 0, 0),
#   'citations': 217,
#   'title': 'Windows Azure Platform'},
#  {'date': datetime.datetime(2004, 7, 5, 0, 0),
#   'citations': 279,
#   'title': "Knowing What You Don't Know? Discourses and Contradictions in Knowledge Management Research"},
#  {'date': datetime.datetime(2004, 3, 1, 0, 0),
#   'citations': 275,
#   'title': 'A real-world way to manage real options.'},
#  {'date': datetime.datetime(2006, 7, 1, 0, 0),
#   'citations': 321,
#   'title': 'Statistics for People Who (Think They) Hate Statistics. Third Edition.'},
#  {'date': datetime.datetime(2014, 11, 1, 0, 0),
#   'citations': 83,
#   'title': 'Innovation Ecosystems'},
#  {'date': datetime.datetime(2008, 5, 1, 0, 0),
#   'citations': 207,
#   'title': 'JavaScript: The Good Parts'},
#  {'date': datetime.datetime(2011, 6, 13, 0, 0),
#   'citations': 163,
#   'title': 'Visualize This'},
#  {'date': datetime.datetime(2000, 11, 1, 0, 0),
#   'citations': 265,
#   'title': 'Problem frames: analyzing and structuring software development problems'},
#  {'date': datetime.datetime(2014, 1, 11, 0, 0),
#   'citations': 76,
#   'title': 'What-You-Prescribe-Is-What-You-Get orthotropic hyperelasticity'},
#  {'date': datetime.datetime(2003, 4, 1, 0, 0),
#   'citations': 261,
#   'title': "'Hitting You Over the Head': Oncologists' Disclosure of Prognosis to Advanced Cancer Patients"},
#  {'date': datetime.datetime(1997, 7, 1, 0, 0),
#   'citations': 276,
#   'title': 'Molecular Biology of Cancer'},
#  {'date': datetime.datetime(2000, 11, 1, 0, 0),
#   'citations': 200,
#   'title': 'Problem Frames - Analysing and Structuring Software Development Problems'},
#  {'date': datetime.datetime(2005, 2, 15, 0, 0),
#   'citations': 195,
#   'title': 'Assessing environmental impacts in a life-cycle perspective.'},
#  {'date': datetime.datetime(2012, 12, 10, 0, 0),
#   'citations': 72,
#   'title': 'Bandit Algorithms for Website Optimization'},
#  {'date': datetime.datetime(1972, 12, 1, 0, 0),
#   'citations': 332,
#   'title': 'Kinetic Theory of Vehicular Traffic'},
#  {'date': datetime.datetime(2013, 11, 26, 0, 0),
#   'citations': 64,
#   'title': 'Applied Network Security Monitoring: Collection, Detection, and Analysis'},
#  {'date': datetime.datetime(2005, 6, 1, 0, 0),
#   'citations': 202,
#   'title': 'How Do You Improve Compliance?'},
#  {'date': datetime.datetime(1984, 7, 1, 0, 0),
#   'citations': 270,
#   'title': 'Walking and running'},
#  {'date': datetime.datetime(2000, 6, 1, 0, 0),
#   'citations': 157,
#   'title': 'System-on-a-Chip'},
#  {'date': datetime.datetime(2013, 11, 18, 0, 0),
#   'citations': 55,
#   'title': 'SysML Distilled: A Brief Guide to the Systems Modeling Language'},
#  {'date': datetime.datetime(2002, 1, 18, 0, 0),
#   'citations': 112,
#   'title': 'Developing Software with UML: Object-Oriented Analysis and Design in Practice'},
#  {'date': datetime.datetime(2005, 9, 1, 0, 0),
#   'citations': 123,
#   'title': 'Asterisk: The Future of Telephony'},
#  {'date': datetime.datetime(1995, 3, 7, 0, 0),
#   'citations': 156,
#   'title': '201 Principles of Software Development'},
#  {'date': datetime.datetime(2006, 9, 20, 0, 0),
#   'citations': 109,
#   'title': "Sometimes size doesn't matter: reevaluating RECIST and tumor response rate endpoints."},
#  {'date': datetime.datetime(1988, 7, 1, 0, 0),
#   'citations': 155,
#   'title': 'Desire as Belief'},
#  {'date': datetime.datetime(1998, 8, 1, 0, 0),
#   'citations': 125,
#   'title': 'Screening for Migraine in the General Population: Validation of A Simple Questionnaire'},
#  {'date': datetime.datetime(1983, 8, 1, 0, 0),
#   'citations': 165,
#   'title': 'Ideals of human excellence and preserving natural environments'},
#  {'date': datetime.datetime(2002, 10, 22, 0, 0),
#   'citations': 94,
#   'title': 'Challenging Behavior in Young Children: Understanding, Preventing, and Responding Effectively'},
#  {'date': datetime.datetime(2005, 3, 1, 0, 0),
#   'citations': 80,
#   'title': '“What you see is what you get”'},
#  {'date': datetime.datetime(1878, 11, 1, 0, 0),
#   'citations': 117,
#   'title': 'The geology of Sussex; or, The geology and fossils of the Tertiary and Cretaceous formations of Sussex'}]

# %%
import requests
import matplotlib.pyplot as plt
from tqdm import tqdm
from datetime import datetime
import time


def search_semantic_scholar(query: str, year: int, field_of_study: str) -> list:
    """
    Search Semantic Scholar API for papers in a specific year and field
    """
    base_url = "https://api.semanticscholar.org/graph/v1/paper/search"
    all_papers = []
    offset = 0
    limit = 100

    with tqdm(desc=f"Fetching papers for {year}", unit="batch") as pbar:
        while True:
            params = {
                "query": query,
                "fields": "title,publicationDate,citationCount,url,year",
                "limit": limit,
                "offset": offset,
                "year": str(year),
                "fieldsOfStudy": field_of_study,
            }
            while True:
                response = requests.get(base_url, params=params)

                if response.status_code == 429:
                    time.sleep(10)
                    continue

                if response.status_code != 200:
                    break

                break

            if response.status_code != 200:
                break

            data = response.json()
            batch_papers = data.get("data", [])

            all_papers.extend(batch_papers)
            pbar.update(len(batch_papers))
            pbar.set_description(f"Year {year}: {len(all_papers)} papers")

            if len(batch_papers) < limit:
                break

            offset += limit
    return all_papers


def create_scatter_plot(all_years_papers):
    """
    Create scatter plot across multiple years
    """
    valid_papers = []
    for papers in all_years_papers:
        for paper in papers:
            try:
                pub_date = datetime.fromisoformat(
                    paper.get("publicationDate", "").rstrip("Z")
                )
                if pub_date and paper.get("citationCount") is not None:
                    valid_papers.append(
                        {
                            "date": pub_date,
                            "citations": paper["citationCount"],
                            "title": paper["title"],
                        }
                    )
            except (ValueError, TypeError, AttributeError):
                continue

    dates = [paper["date"] for paper in valid_papers]
    citations = [paper["citations"] for paper in valid_papers]

    plt.figure(figsize=(15, 8))
    scatter = plt.scatter(dates, citations, alpha=0.7, c=citations, cmap="viridis")
    plt.colorbar(scatter, label="Citation Count")
    plt.title('"Is All You Need" Paper Analysis')
    plt.xlabel("Publication Date")
    plt.ylabel("Citation Count")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig("is_all_you_need_papers.png", dpi=300, bbox_inches="tight")

    return valid_papers


# Main execution
query = '"is all you need"'
field_of_study = "Computer Science"
# Search for papers by year
years = range(2010, 2026)
all_years_papers = [
    search_semantic_scholar(query, year, field_of_study) for year in years
]

# Create scatter plot
analyzed_papers = create_scatter_plot(all_years_papers)
print(f"Total analyzed papers: {len(analyzed_papers)}")
# Out:
# Year 2010: 723 papers: : 723batch [00:09, 77.16batch/s]
# Year 2011: 635 papers: : 635batch [00:06, 95.46batch/s]
# Year 2012: 742 papers: : 742batch [00:09, 74.34batch/s]
# Year 2013: 779 papers: : 779batch [00:09, 78.84batch/s]
# Year 2014: 757 papers: : 757batch [00:12, 58.76batch/s]
# Year 2015: 732 papers: : 732batch [00:09, 78.40batch/s]
# Year 2016: 696 papers: : 696batch [00:07, 97.18batch/s]
# Year 2017: 521 papers: : 521batch [00:08, 61.33batch/s]
# Year 2018: 567 papers: : 567batch [00:05, 94.78batch/s]
# Year 2019: 562 papers: : 562batch [00:06, 82.33batch/s]
# Year 2020: 465 papers: : 465batch [00:07, 64.17batch/s]
# Year 2021: 480 papers: : 480batch [00:04, 111.52batch/s]
# Year 2022: 459 papers: : 459batch [00:05, 86.02batch/s]
# Year 2023: 528 papers: : 528batch [00:07, 75.32batch/s]
# Year 2024: 497 papers: : 497batch [00:05, 94.94batch/s]
# Year 2025: 39 papers: : 39batch [00:00, 55.99batch/s]
# Total analyzed papers: 6255

# %%
"""
Create scatter plot across multiple years
"""
valid_papers = []
for papers in all_years_papers:
    for paper in papers:
        try:
            pub_date = datetime.fromisoformat(
                paper.get("publicationDate", "").rstrip("Z")
            )
            if pub_date and paper.get("citationCount") is not None:
                valid_papers.append(
                    {
                        "date": pub_date,
                        "citations": paper["citationCount"],
                        "title": paper["title"],
                    }
                )
        except (ValueError, TypeError, AttributeError):
            continue

dates = [paper["date"] for paper in valid_papers]
citations = [paper["citations"] for paper in valid_papers]

plt.figure(figsize=(15, 8))
scatter = plt.scatter(dates, citations, alpha=0.7, c=citations, cmap="viridis")
plt.colorbar(scatter, label="Citation Count")
plt.title('"Is All You Need" Paper Analysis')
plt.xlabel("Publication Date")
plt.ylabel("Citation Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("is_all_you_need_papers.png", dpi=300, bbox_inches="tight")

# %%
# Option 2
from itertools import chain

flattened_papers = list(chain(*all_years_papers))

# %%
import pandas as pd
import re

df = pd.DataFrame(flattened_papers)
df = df[
    df.title.apply(
        lambda x: re.match(".*(is|are) all you need.*", x, re.IGNORECASE) is not None
    )
]

# %%
fig, ax = plt.subplots(figsize=(4, 4))
plt.style.use("orange_dark")

df = df[~df.publicationDate.str[:4].isnull()]
df["year"] = df.publicationDate.str[:4].astype(int)
plot_data = df.groupby("year", as_index=False).count()
plot_data.plot.bar(x="year", y="citationCount", ax=ax, width=0.8)
ax.legend().remove()
plt.xticks(rotation=45)

# Add annotation
year_2017_idx = plot_data[plot_data.year == 2017].index[0]
count_2017 = plot_data[plot_data.year == 2017].citationCount.values[0]
ax.annotate(
    "Attention is all you need",
    xy=(year_2017_idx, count_2017 + 5),  # point to annotate
    xytext=(year_2017_idx - 2, count_2017 + 80),  # text position
    arrowprops=dict(
        # facecolor="black",
        shrink=0.05,
        width=0.5,  # width of arrow
        headwidth=5,  # width of arrow head
    ),  # arrow properties
)
ax.set_title("Article titles containing \n'is all you need'")
plt.tight_layout()
plt.savefig("image.svg", format="svg")

# %%
df.sort_values("citationCount", ascending=False)
# Out:
#                                        paperId  \
# 5064  204e3073870fae3d05bcbc2f6a8e263d9b72e776
# 5586  5b01eaef54a653ba03ddd5a978690380fbc19bfc
# 6717  80455126562cfe6a483e02b3446a3f30b8e9f229
# 6716  6568423cfaca7e24c88ea208cb0e67129e43aa9b
# 6715  9c160a71d3265eedaf7645c39be073c966f10433
# ...                                        ...
# 8748  f327cebe19471ff8284948f7daddd36e15319d70
# 8749  f1b080857cbc8de7730e5f02069992b8d58fd073
# 8750  46d3eeafc78bbe750f181271e73a57733705362e
# 8751  1eced8cb15c9ff7648e884b48c065f3b72cb934e
# 9151  586f31fb1f07c247770b46209c9e6a5507807157
#
#                                                     url  \
# 5064  https://www.semanticscholar.org/paper/204e3073...
# 5586  https://www.semanticscholar.org/paper/5b01eaef...
# 6717  https://www.semanticscholar.org/paper/80455126...
# 6716  https://www.semanticscholar.org/paper/6568423c...
# 6715  https://www.semanticscholar.org/paper/9c160a71...
# ...                                                 ...
# 8748  https://www.semanticscholar.org/paper/f327cebe...
# 8749  https://www.semanticscholar.org/paper/f1b08085...
# 8750  https://www.semanticscholar.org/paper/46d3eeaf...
# 8751  https://www.semanticscholar.org/paper/1eced8cb...
# 9151  https://www.semanticscholar.org/paper/586f31fb...
#
#                                                   title  year  citationCount  \
# 5064                          Attention is All you Need  2017         115266
# 5586  Diversity is All You Need: Learning Skills wit...  2018           1001
# 6717  Rethinking Few-Shot Image Classification: a Go...  2020            834
# 6716  Image Augmentation Is All You Need: Regularizi...  2020            718
# 6715  A Lip Sync Expert Is All You Need for Speech t...  2020            656
# ...                                                 ...   ...            ...
# 8748  Inference is All You Need: Self Example Retrie...  2024              0
# 8749  One Homography is All You Need: IMM-based Join...  2024              0
# 8750  Epigenetics is all you need: A Transformer to ...  2024              0
# 8751  Randomness Is All You Need: Semantic Traversal...  2024              0
# 9151          Kolmogorov GAM Networks are all you need!  2025              0
#
#      publicationDate
# 5064      2017-06-12
# 5586      2018-02-16
# 6717      2020-03-25
# 6716      2020-04-28
# 6715      2020-08-23
# ...              ...
# 8748      2024-09-10
# 8749      2024-09-04
# 8750      2024-07-19
# 8751      2024-02-08
# 9151      2025-01-01
#
# [507 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(6, 3))

plt.scatter(pd.to_datetime(df.publicationDate), df.citationCount, alpha=0.7)
plt.ylim(1, 1000)
plt.xlabel("Publication Date")
plt.ylabel("Citation Count")
plt.tight_layout()
plt.savefig("image3.svg", format="svg")
# plt.yscale("log")

# %%
import numpy as np

# Create figure with two subplots
fig, (ax1, ax2) = plt.subplots(
    2, 1, figsize=(6, 3), gridspec_kw={"hspace": 0, "height_ratios": [2, 1]}
)
plt.style.use(f"{ROOT}/orange_dark.mplstyle")

# Top subplot: Quantile function
quantiles = np.linspace(0, 1, 100)
citation_quantiles = np.percentile(df["citationCount"], quantiles * 100)
ax1.plot(citation_quantiles, 1 - quantiles, color="white", linewidth=2)
ax1.fill_betweenx(1 - quantiles, 0, citation_quantiles, alpha=0.3, color="orange")
ax1.set_xscale("log")
# ax1.set_ylabel("Quantile")
ax1.spines["bottom"].set_visible(False)

# Bottom subplot: Strip plot
sns.stripplot(
    data=df, x="citationCount", ax=ax2, alpha=0.4, size=8, jitter=0.3, color="orange"
)
ax2.set_xscale("log")
ax2.set_yticks([])
# ax2.spines["top"].set_visible(False)

# Share the x-axis
ax2.sharex(ax1)
plt.tight_layout()
plt.savefig("image4.svg", format="svg")

# %%
import numpy as np

plt.style.use(f"{ROOT}/orange_dark.mplstyle")
# Calculate proportions for each citation count
proportions = df["citationCount"].value_counts() / len(df)

# Create specific buckets
buckets = {
    "0": (proportions[0] if 0 in proportions else 0),
    "1": (proportions[1] if 1 in proportions else 0),
    "2": (proportions[2] if 2 in proportions else 0),
    "3": (proportions[3] if 3 in proportions else 0),
    "4": (proportions[4] if 4 in proportions else 0),
    "5": (proportions[5] if 5 in proportions else 0),
    ">5": sum(proportions[i] for i in proportions.index if i > 5),
}

# Create bar plot
plt.figure(figsize=(4, 4))
plt.bar(buckets.keys(), 100 * np.array(list(buckets.values())))
plt.title("Distribution of Citations")
plt.ylabel("Proportion of Papers [%]")
plt.xlabel("Citation Count")
plt.tight_layout()
plt.savefig("image2.svg", format="svg")

# %%
df.to_csv("data.csv", index=False)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Read the CSV file
df = pd.read_csv("data.csv")

# %%
fig, ax = plt.subplots(
    1,
    2,
    figsize=(9, 4),
    gridspec_kw={"hspace": 0.25},  # Changed from 0 to 0.2
)
plt.style.use("newsletter")
proportions = df["citationCount"].value_counts() / len(df)

# Create specific buckets
buckets = {
    "0": (proportions[0] if 0 in proportions else 0),
    "1": (proportions[1] if 1 in proportions else 0),
    "2": (proportions[2] if 2 in proportions else 0),
    "3": (proportions[3] if 3 in proportions else 0),
    "4": (proportions[4] if 4 in proportions else 0),
    "5": (proportions[5] if 5 in proportions else 0),
    ">5": sum(proportions[i] for i in proportions.index if i > 5),
}

# Create bar plot
ax[1].bar(buckets.keys(), 100 * np.array(list(buckets.values())))
ax[1].set_title("Distribution of Citations")
ax[1].set_ylabel("Proportion of Papers [%]")
ax[1].set_xlabel("Citation Count")

#
# figure 0
#
df = df[~df.publicationDate.str[:4].isnull()]
df["year"] = df.publicationDate.str[:4].astype(int)
plot_data = df.groupby("year", as_index=False).count()
plot_data.plot.bar(x="year", y="citationCount", ax=ax[0], width=0.8)
ax[0].legend().remove()
plt.setp(ax[0].get_xticklabels(), rotation=45)  # Correct way to set tick rotation

# Add annotation
year_2017_idx = plot_data[plot_data.year == 2017].index[0]
count_2017 = plot_data[plot_data.year == 2017].citationCount.values[0]
ax[0].annotate(
    "Attention is all you need",
    xy=(year_2017_idx, count_2017 + 5),  # point to annotate
    xytext=(year_2017_idx - 2.5, count_2017 + 80),  # text position
    arrowprops=dict(
        # facecolor="black",
        shrink=0.05,
        width=0.5,  # width of arrow
        headwidth=5,  # width of arrow head
    ),  # arrow properties
)
ax[0].set_title("Article titles containing \n'is all you need'")
plt.tight_layout()

# // ... existing code ...

# Create bar plot
bars = ax[0].patches[0]  # Get the first bar to extract its color
color = bars.get_facecolor()  # Get the color from the first plot
ax[1].bar(buckets.keys(), 100 * np.array(list(buckets.values())), color=color)

plt.savefig("image2.png", format="png")
# // ... existing code ...
# ax[1].savefig("image2.svg", format="svg")
# Out:
# /var/folders/g6/gqdf2y4n3jj4f0vml_0s_q1r0000gn/T/ipykernel_98821/4250004340.py:52: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
dark_style = plt.style.library["dark_background"]

# Print color-related settings
for key, value in dark_style.items():
    if "color" in key:
        print(f"{key}: {value}")
# Out:
# axes.edgecolor: white
# axes.facecolor: black
# axes.labelcolor: white
# boxplot.boxprops.color: white
# boxplot.capprops.color: white
# boxplot.flierprops.color: white
# boxplot.flierprops.markeredgecolor: white
# boxplot.whiskerprops.color: white
# figure.edgecolor: black
# figure.facecolor: black
# grid.color: white
# lines.color: white
# patch.edgecolor: white
# text.color: white
# xtick.color: white
# ytick.color: white

# %%
import matplotlib.font_manager as fm

available_fonts = [f.name for f in fm.fontManager.ttflist]
[name for name in available_fonts if "fira" in name.lower()]
# Out:
# ['FiraCode Nerd Font']

# %%
possible_paths = [
    "/Library/Fonts/FiraCode-Regular.ttf",
    "/System/Library/Fonts/FiraCode-Regular.ttf",
    os.path.expanduser("~/Library/Fonts/FiraCode-Regular.ttf"),
    # Add more paths if needed
]

# Print found font files
print("Checking common font locations:")
for path in possible_paths:
    if os.path.exists(path):
        print(f"Found: {path}")

# Rebuild the font cache
fm.fontManager.addfont(
    "/Users/mac-robertsocolewicz/Library/Fonts/FiraCodeNerdFont-Regular.ttf"
)  # Adjust path based on output above
fm._load_fontmanager(try_read_cache=False)
# Out:
# Checking common font locations:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib

print(matplotlib.get_configdir())
# Out:
# /Users/mac-robertsocolewicz/.matplotlib

# %%
base_url = "https://api.semanticscholar.org/graph/v1/paper/search"
query = '"is all you need"'
params = {
    "query": query,
    "fields": "title,publicationDate,citationCount,url,fieldsOfStudy,year",
    "limit": 1,
    "offset": 0,
    "year": str(2024),
    "fieldsOfStudy": field_of_study,
}
response = requests.get(base_url, params=params)
response.json()
# Out:
# {'total': 488,
#  'offset': 0,
#  'next': 1,
#  'data': [{'paperId': 'f0f0b680ac74960922634e3da5cf1e6f6883c840',
#    'url': 'https://www.semanticscholar.org/paper/f0f0b680ac74960922634e3da5cf1e6f6883c840',
#    'title': 'Protein generation with evolutionary diffusion: sequence is all you need',
#    'year': 2024,
#    'citationCount': 62,
#    'fieldsOfStudy': ['Biology'],
#    'publicationDate': '2024-11-04'}]}

# %%
years = range(2024, 2026)
delta = [search_semantic_scholar(query, year, field_of_study) for year in years]
# Out:
# Year 2024: 488 papers: : 488batch [00:04, 101.61batch/s]
# Year 2025: 23 papers: : 23batch [00:00, 31.93batch/s]

# %%
all_years_papers.extend(delta)
