# %%
import matplotlib.pyplot as plt
import numpy as np
from dotenv import find_dotenv
import os

ROOT = os.path.dirname(find_dotenv())

plt.style.use(f"{ROOT}/orange_dark.mplstyle")
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.savefig("hello.svg", format="svg")
